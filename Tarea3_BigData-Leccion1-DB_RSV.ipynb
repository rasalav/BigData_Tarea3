# %% [markdown]
# # PROGRAMA DE CIENCIAS DE LOS DATOS
# ## **CURSO: BIG DATA**
# ### **TAREA #3**
#
# Profesor: MSc. Felipe Meza
#
#
# Alumno:
#
#   Randal Salazar Viales

# %% [markdown]
# ![logo](logo.png "Logo")
#
# # Módulo 4 - Big Data
#
# Autor: Juan Esquivel

# %% [markdown]
# # Objetivos
#
# ## General
# Entender y aplicar técnicas de análisis de grandes cantidades de datos para la resolución de problemas concretos a través de tecnologías de manipulación, extracción y sintetización estadística.
#
# ## Específicos
# - Aplicar bibliotecas para la transformación de datos a gran escala para poder sintetizar el conocimiento para futuro análisis.
# - Aplicar técnicas de análisis de datos para extraer patrones que mejoren el entendimiento de un problema concreto.
# - Aplicar técnicas para aprendizaje automatizado de patrones, basado en datos existentes, para mejorar la certeza de la solución aplicada a problemas concretos.
#
#
# # Contenidos
#
# - Introducción a procesamiento a gran escala
# - Fuentes y repositorios de datos
# - Procesamiento de fuentes (data frames)
# - Procesamiento de atributos
# - Organización de datos procesados
# - Análisis de datos a gran escala
# - Uso de modelos de aprendizaje automático a gran escala
#
# # Evaluación
#
# - Tareas Cortas 70%
# - Proyecto 30%

# %% [markdown]
# # Procesamiento de datos a gran escala
# Hoy día es relativamente sencillo tener cantidades muy considerables de datos en una organización, sin tan siquiera darse cuenta. El almacenamiento, local o en la nube, ha llegado a un punto que nos permite simplemente almacenar más y más datos sin tener que preocuparse por costos de almacenamiento. Cualquier sistema de ventas, por ejemplo, almacena información diaria sobre clientes, transacciones, tiendas, productos, etc. Después de un par de años de acumular datos, un programa que *funcionaba bien* de pronto empieza a sufrir efectos de degradación de servicio, debido al crecimiento orgánico de los datos.
#
# Aún más, es más común que no sea factible tener todos los datos relacionados a un problema en una sola máquina física. Por ello, es necesario particionar los datos y distribuirlos en granjas de servidores de almacenamiento. Algunas definiciones colocan la línea limítrofe de Big Data utilizando esa barrera de almacenamiento distribuído.
#
# ## Lectura y transformación de datos a gran escala
# El mayor tamaño de las fuentes de datos requiere que, para obtener información estratégica, se deba implementar elementos de software que permitan procesar y resumir los datos. Normalmente se refiere a ésto como *ETL: Extract, Transform and Load*.
#
# Primero, los datos deben *Extraerse* de las fuentes. Después, deben ser *Transformados*, ya sea para crear datos más complejos o ajustar para que sea compatible con el destino. Por último, los datos deben ser *Cargados* a un medio donde serán consumidos por los usuarios.
#
# A lo largo de la última década, la necesidad de administrar procesos *ETL* a gran escala se ha convertido en un imperativo para un científico de datos. Esto se realiza, comúnmente, utilizando *frameworks* de alta escalabilidad basados en un modelo de programación llamado *MapReduce*. En esencia, la idea es no pensar sobre los datos como conjuntos enormes de información, sino reducir las operaciones a qué debe realizarse "fila por fila". Queremos aplicar operaciones individuales a cada elemento, independiente de cualquier otro en la colección (al menos en teoría). Las operaciones que modifican cada elemento se llaman funciones *map*. Adicionalmente, podemos generar operaciones que sinteticen múltiples elementos que corresponden a la misma entidad reducidendólos a un solo elemento (*reduce*). Plataformas modernas ya no se apegan al espíritu exacto de *MapReduce*, sin embargo, las ideas básicas se mantienen igual.
#
# En las siguiente sección introducimos los conceptos clásicos de *MapReduce*. Posteriormente, realizaremos una introducción práctica a frameworks contemporáneos. En este módulo utilizaremos Apache Spark para mostrar los conceptos básicos de este tipo de procesamiento.

# %% [markdown]
# # Motivación MapReduce
# El problema resuelto por *MapReduce* se ilustra con el ejemplo clásico de la frecuencia de palabras en una colección abundante de texto. Si tenemos un corpus compuesto por millones de libros de texto, podríamos pensar en un algoritmo de fuerza bruta que representa cada libro como un arreglo de tipo `string`:
# ```
# func count(words []string) {
#   var counts map[string]int
#
#   for _, word:=range words {
#     counts[word] += 1
#   }
#   printSorted(counts)
# }
# ```
#
# En Go el anterior ejemplo puede alcanzar órdenes de magnitudes de centenas de millones, convirtiéndose la memoria en el cuello de botella primario. Es posible que el procesamiento no requiera todas las palabras en memoria, utilizando canales de transmisión (`channel` en Go). Sin embargo, cuando todas las palabras son únicas aún tenemos problemas.
#
# Si dejamos los linderos de una máquina individual y asumimos que tenemos, por ejemplo, 10 núcleos de procesamiento. Podríamos dividir el total de los datos en 10 partes, cada núcleo puede generar conteos para cada segmento de datos y, posteriormente, lo envía a un controlador. El controlador procedería a integrar todos los conteos.
#
# Si queremos repetir este proceso con 1000 máquinas, un solo controlador colapsaría. Podemos agregar una jerarquía de controladores, sin embargo, donde cada 10 máquina envía a un controlador intermedio y esos, a su vez, a un controlador mayor.
#
# Cuando se trabaja con un número tan elevado de núcleos de procesamiento, la probabilidad de que alguna máquina presente errores se incrementa. Si definimos el error que una sola máquina falle como $\epsilon=0.001$ podemos definir la probabilidad que 10 máquinas ejecuten el proceso sin tener errores como $(1-\epsilon)^{10}=0.999^{10}=0.9900448802$. Esto quiere decir que en más del 99% de las ejecuciones no debería existir errores en las máquinas y, por lo tanto, la tarea debería concluirse exitosamente. El mismo razonamiento para 1000 máquinas, sin embargo, nos da una probabilidad que todos los núcleos sean exitosos de 37%, únicamente ($(1-\epsilon)^{1000}=0.999^{1000}=0.3676954248$.
#
# Esto quiere deir que el modelado debe incorporar tolerancia a fallos integralemente, replicando las entradas (3 copias), distribuyendo el mismo trabajo entre máquinas no relacionadas entre sí, utilización de checksums, etc.
#
# ## Detalles de MapReduce
# De acuerdo a su publicación original *MapReduce* es un modelo de programación para procesar y generar grandes conjuntos de datos. Todo el procesamiento se basa en expresar los datos en pares *llave/valor*. Se debe definir una función de mapeo de los pares originales a una representación intermedia que, posteriormente, es tomada por una función de reducción que une todas las llaves en una sola entrada. Existe una fase oculta a los usuarios que ordena los datos (*shuffle*) previo a la reducción. Si se tienen $R$ máquinas a cargo de la reducción, la fase de shuffle asigna los datos intermedios al nodo con índice `hash(key) % R`.
#
# En gran medida, la popularidad de este modelo es que una gran cantidad de problemas reales se pueden modelar de esta forma. Además, los autores crearon un ambiente de ejecución donde los programas escritos en esta forma eran paralelizados y ejecutados de forma distribuida de manera automática.
#
# Para el ejemplo del conteo de frecuencias de palabras, el algoritmo para resolverlo sería:
#
# ```
# map(String key, String[] value):
#   // key: document name
#   // value: document contents
#   for each word in value:
#     EmitIntermediate(w, "1")
#
# reduce(String key, Iterator values):
#   // key: a word
#   // values: a list of counts
#   int result = 0;
#   for each v in values:
#     result += ParseInt(v);
#   Emit(AsString(result));
# ```
#
# El siguiente diagrama muestra el proceso completo que efectúa el ambiente de ejecución de *MapReduce*.
#
# ![mapreduce](mr.png "Map Reduce")
#
# ## Limitaciones de MapReduce
# Como se mencionó anteriormente, los problemas resueltos por MapReduce *deben* expresarse como una colección de elementos *llave/valor*. De no ser posible, no se puede utilizar el framework para bordarlos.
#
# Además, tiene problemas con algoritmos que son iterativos, debido a que en la fase del mapeo se asume que cada elemento es independiente de otros.

# %% [markdown]
# # Datos de ejemplo
# A manera de ejemplo, asumiremos que una tienda en línea almacena las compras de sus clientes en una base de datos PostgreSQL. Aplicaremos ciertas operaciones básicas sobre los datos para mostrar lo que este tipo de plataformas ofrecen. A continuación, un ejemplo básico de modelo de datos, que se usará posteriormente.
#
# ```sql
# CREATE TABLE transactions (
#   id SERIAL PRIMARY KEY,
#   customer_id integer NOT NULL,
#   amount integer NOT NULL,
#   purchased_at timestamp without time zone NOT NULL
# );
#
#
# INSERT INTO "transactions" (customer_id, amount, purchased_at) VALUES
# (1, 55, '2017-03-01 09:00:00'),
# (1, 125, '2017-03-01 10:00:00'),
# (1, 32, '2017-03-02 13:00:00'),
# (1, 64, '2017-03-02 15:00:00'),
# (1, 128, '2017-03-03 10:00:00'),
# (2, 333, '2017-03-01 09:00:00'),
# (2, 334, '2017-03-01 09:01:00'),
# (2, 333, '2017-03-01 09:02:00'),
# (2, 11, '2017-03-03 20:00:00'),
# (2, 44, '2017-03-03 20:15:00');
# ```
#
# # Apache Spark
#
# Existen multiples *frameworks* para procesar datos a gran escala. Para el propósito de esta clase, utilizaremos Apache Spark ya que es un proyecto abierto que ha sido adoptado por una gran candidad de desarrolladores y también es un motor primario en servicios en la nube, como Amazon Web Services.
#
# Spark está basado en una abstracción llamada *Resilient Distributed Dataset* (RDD) que es una colección de elementos que pueden ser almacenados, temporal o permanentemente, a lo largo de múltuples nodos físicos de un cluster. Spark permite el uso de múltiples fuentes de datos, desde SQL y NoSQL hasta archivos de texto plano. La tarea primaria de un programador es diseñar las operaciones sucesivas par transformar el RDD de su forma original a la salida deseada.
#
# El siguiente ejemplo de código utiliza la base de datos descrita anteriormente y muestra el contenido almacenado en ella. Nótese que si la tabla fuera muy grande llamar al método `show()` no es recomendable.

# %% [markdown]
# # **** INICIO DE GENERADOR DE TRANSACCIONES ****

# %% [markdown]
# # TAREA_3: GENERADOR DE TRANSACCIONES

# %% [markdown]
# ## Conexión a POSTGRESQL desde Jupyter Notebook para:
# ## Crear Tabla Transactions y descargar 1000 transaccions creadas aleatoriamente

# %% [markdown]
# Comenzamos con la importación de librerías y demás parámetros necesarios...
#
# ### Importación de Librerías

# %%
# Librería de adaptador ente Python y PostgreSQL: psycopg2
import psycopg2

# %% [markdown]
# ### Definición de variables de conexión entre Psycopg2 y PostgreSQL

# %%
# Variables de conexión
var_conexion = "host='localhost' dbname='test' user='postgres' password='bd2019%' "

# Impresión de las Variables de Conexión
print("Variables de conexión a la BD:\n -> ",  var_conexion)
# Out:
# Variables de conexión a la BD:
#  ->  host='localhost' dbname='test' user='postgres' password='bd2019%'

# %% [markdown]
# Para fines de la Tarea3, la conexión, carga de datos y consultas, será a la BD PostgreSQL = **test**

# %% [markdown]
# ### Crear objeto de conexión entre Psycopg2 y la BD PostgreSQL

# %%
# Objeto que contenga las Variables de Conexión
obj = psycopg2.connect(var_conexion)

# Objeto Cursor: para enviar Queries (Consultas) a la BD
# Activar conexión del cursor
objCursor = obj.cursor()

# %% [markdown]
# ### Consultas SQL a la BD en PostgreSQL

# %% [markdown]
# Verificación de que se está conectado en la BD: consulta a tabla **tbltest** existente.

# %%
# Consulta a la BD 
objCursor.execute("SELECT * FROM tbltest;")
filas = objCursor.fetchall()
filas
# Out:
# [(10, 'Josue Beltran'),
#  (18, 'Ana Navarro'),
#  (50, 'Guillermo Soto'),
#  (15, 'Juan Céspedes'),
#  (26, 'Enrique Cortez')]

# %% [markdown]
# ### Verificación de si existe la tabla Transactions en la BD Test en PostgreSQL

# %%
# Consulta a la BD 
objCursor.execute("SELECT exists (Select 1 FROM transactions);")
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-5-3a476c1942e3> in <module>
#       1 # Consulta a la BD
# ----> 2 objCursor.execute("SELECT exists (Select 1 FROM transactions);")
#
# UndefinedTable: no existe la relación «transactions»
# LINE 1: SELECT exists (Select 1 FROM transactions);
#                                      ^

# %% [markdown]
# Como se puede apreciar la tabla transactions **NO EXISTE** en la BD que se está empleando. Se procederá a cerra la conexión debido a que el error anterior, provoca que NO se pueda efectuar consultas a la BD, luego se abrirá nuevamente la conexión para poder crear la tabla y efetuar las transacciones.

# %% [markdown]
# ### Cerrar la conexión entre Psycopg2 y la BD PostgreSQL

# %%
# Cierre de objeto cursor
objCursor.close()

# Cierre del objeto de las Variables de Conexión
obj.close()

# %% [markdown]
# ### Abrir nuevamente conexión con BD PostgreSQL
# ### Crear objeto de conexión entre Psycopg2 y la BD PostgreSQL

# %%
# Objeto que contenga las Variables de Conexión
obj = psycopg2.connect(var_conexion)

# Objeto Cursor: para enviar Queries (Consultas) a la BD
# Activar conexión del cursor
objCursor = obj.cursor()

# %% [markdown]
# ### Creación de la tabla "transactions" en la BD

# %%
# Creación de la tabla transactions en la BD
objCursor.execute("CREATE TABLE transactions\
                  (id SERIAL PRIMARY KEY,\
                  customer_id integer NOT NULL,\
                  amount integer NOT NULL,\
                  purchased_at timestamp without time zone NOT NULL);")
#filas = objCursor.fetchall()
#filas

# %% [markdown]
# ### Confirmación permanente (finalización de la transacción) de creación de tabla "transactions" en BD

# %%
# Guardar el Cambio permanente 
obj.commit()

# %% [markdown]
# ### Consulta de datos existentes en la tabla "transactions" creada

# %%
# Consulta a la BD 
objCursor.execute("SELECT * FROM transactions;")
filas = objCursor.fetchall()
filas
# Out:
# []

# %% [markdown]
# ### Inserción de datos dados en la Notebook inicial dentro de la tabla "transactions" creada

# %%
# Inserción de 10 datos dados en la Notebook, en  de la tabla 'transactions' de la BD "test"
objCursor.execute("INSERT INTO transactions (customer_id, amount, purchased_at) VALUES\
                  (1, 55, '2017-03-01 09:00:00'),\
                  (1, 125, '2017-03-01 10:00:00'),\
                  (1, 32, '2017-03-02 13:00:00'),\
                  (1, 64, '2017-03-02 15:00:00'),\
                  (1, 128, '2017-03-03 10:00:00'),\
                  (2, 333, '2017-03-01 09:00:00'),\
                  (2, 334, '2017-03-01 09:01:00'),\
                  (2, 333, '2017-03-01 09:02:00'),\
                  (2, 11, '2017-03-03 20:00:00'),\
                  (2, 44, '2017-03-03 20:15:00');")

# %% [markdown]
# ### Verificación de que se ingresó los datos anteriores en la tabla "transactions"

# %%
# Consulta a la BD 
objCursor.execute("SELECT * FROM transactions;")
filas = objCursor.fetchall()
filas
# Out:
# [(1, 1, 55, datetime.datetime(2017, 3, 1, 9, 0)),
#  (2, 1, 125, datetime.datetime(2017, 3, 1, 10, 0)),
#  (3, 1, 32, datetime.datetime(2017, 3, 2, 13, 0)),
#  (4, 1, 64, datetime.datetime(2017, 3, 2, 15, 0)),
#  (5, 1, 128, datetime.datetime(2017, 3, 3, 10, 0)),
#  (6, 2, 333, datetime.datetime(2017, 3, 1, 9, 0)),
#  (7, 2, 334, datetime.datetime(2017, 3, 1, 9, 1)),
#  (8, 2, 333, datetime.datetime(2017, 3, 1, 9, 2)),
#  (9, 2, 11, datetime.datetime(2017, 3, 3, 20, 0)),
#  (10, 2, 44, datetime.datetime(2017, 3, 3, 20, 15))]

# %% [markdown]
# ### Cantidad de datos dentro de la tabla "transactions"

# %%
# Consulta a la BD 
objCursor.execute("SELECT count(*) FROM transactions;")
filas = objCursor.fetchall()
filas
# Out:
# [(10,)]

# %% [markdown]
# ### Generador de transacciones aleatorias, para: customer_id = 5, Cantidad transacciones = 1000

# %%
# Generador de Transacciones

# Importación de Librerías
import random
import numpy as np
import time

# c) Generador de fechas:

from datetime import datetime
#from time import gmtime, strftime
from time import localtime, strftime

# Cantidad de transacciones a generar:
Total_Transactions = 1000

# Constantes
# Máxima cantidad customer_id
max_customer = 5
# Máxima cantidad amount
max_amount = 1000
# Hora Máxima para Generar Transacciones
val_purchased = strftime("%Y-%m-%d %H:%M:00", localtime())
# Hora Máxima
hora_max = 18
# Hora Mínima
hora_min = 8

#print(hora_min, hora_max)
print('Fecha de Finalización Transacciones: ')
print(val_purchased)
print(' ')
#print('Hora de Finalización Transacciones: ')

# current date and time (mseconds)
now = datetime.now()
print("date and time:",now)

# current time
time = now.strftime("%H:%M:%S")
print("time:", time)

# current Year
yR = now.strftime("%Y")
print("Year:", yR)
#print("Tipo:", type(yR))
print(' ')

# current Month
mR = now.strftime("%m")
print("Month:", mR)
#print("Tipo:", type(mR))
print(' ')

# current Day
dR = now.strftime("%d")
print("Day:", dR)
#print("Tipo:", type(dR))
print(' ')

# current hour
HR = now.strftime("%H")
print("hour:", HR)
#print("Tipo:", type(HR))
print(' ')

# current minute
MR = now.strftime("%M")
print("minute:", MR)
#print("Tipo:", type(HR))
print(' ')

# Variables a generar
val_customer_id = 0
val_amount = 0
val_purchased_at = ' '
hora_lim = 0

# Matriz Temporal: contador de customer_id generados
# Fila = customer_id de referencia
# Columna 0 = Cantidad de veces que ha salido customer_id
# Columna 1 = Cantidad de días hacia atrás generados
# Columna 2 = Hora a generar la transacción
# Columna 3 = Minuto a generar la transacción
customer_count = np.zeros((max_customer, 4), dtype=int)

customer_date = np.array((max_customer, 4), dtype=str)
#print(customer_count)

# Initialize internal state of the random number generator.
random.seed(13)

# Definición de hora límite: Hora_Registro u Hora_Max
if ((int(HR) < hora_lim) or (int(HR) >= hora_max)):
    hora_lim = hora_max
else:
    hora_lim = int(HR)

print(' ')
#print('Hora Límite: ', hora_lim)
#print(hora_lim)
print (' ')

# Cálculo de cuántas iteraciones debo efectuar para cada customer_id
(cociente, resto) = divmod(Total_Transactions,max_customer)

# Generador de transacciones
if ((resto == 0) or (resto != 0)):
    # Basta con repartir transacciones entre customer_id
    for x in list(range(1, Total_Transactions + 1)):
        # a) Generador de customer_id:
        # Integer from 1 to max_customer, endpoints included
        val_customer_id = random.randint(1, max_customer)
        #print(val_customer_id )
        # Valor de val_customer_id en la matriz
        val_customer_id = val_customer_id - 1
        #print('Modificado: ', val_customer_id)
        # Actualización de de veces que ha salidos valor de customer_id en matriz de datos
        customer_count [val_customer_id, 0] = customer_count [val_customer_id, 0] + 1
        
        # b) Generador de amount:
        # Integer from 1 to 1000, endpoints included
        val_amount = random.randint(1, max_amount)
        
        # c) Generador de fechas:
        # Actualización de Fecha de Transacción a Generar
        # Dependiendo de la Cantidad de Valores Generados por c/customer
        # Cantidad = 1
        if (customer_count[val_customer_id, 0] == 1):
            # Actualización de Hora
            customer_count[val_customer_id, 2] = hora_min
            # Caso Hora < Hora_min
            if (int(HR) < hora_min):
                # Actualización de Día:
                customer_count[val_customer_id, 1] = customer_count[val_customer_id, 1] + 1
        else:
            # Cantidad >= 2
            # Si Día = 0
            if (customer_count[val_customer_id, 1] == 0):
                # Actualización de Minutos
                customer_count[val_customer_id, 3] = customer_count[val_customer_id, 3] + 1
                # Actualización de Horas
                customer_count[val_customer_id, 2] = hora_min
                # Caso Hora < Hora_min
                if (int(HR) < hora_min):
                    # Actualización de Día:
                    customer_count[val_customer_id, 1] = customer_count[val_customer_id, 1] + 1
            else:
                 # Si Día >= 1
                    # Si Minutos +1 > MR
                    if ((customer_count[val_customer_id, 3] + 1) > int(MR)):
                        # Caso Hora + 1 > HR
                        if ((customer_count[val_customer_id, 2] + 1) > int(HR)):
                            # Actualización de Minutos
                            customer_count[val_customer_id, 3] = 0
                            # Actualización de Horas
                            customer_count[val_customer_id, 2] = 0
                            # Actualización de Día:
                            customer_count[val_customer_id, 1] = customer_count[val_customer_id, 1] + 1
                        else:
                            # Actualización de Minutos
                            customer_count[val_customer_id, 3] = customer_count[val_customer_id, 3] + 1
                    else:
                        # Actualización de Minutos
                        customer_count[val_customer_id, 3] = customer_count[val_customer_id, 3] + 1
                        
        #print(val_customer_id + 1, val_amount)
        #print(customer_count)    

        import time
        # Creación de datetime (Fecha y Hora) de Compra de la transacción:
        # t = (Year, Month, Day, Hour, Minute, Seconds, wday, yday, isdst )
        
        # Valores de: día - hora - min, de la transacción
        dia_trans = int(dR) - customer_count[val_customer_id, 1]
        hora_trans = customer_count[val_customer_id, 2]
        min_trans = customer_count[val_customer_id, 3]
        
        t = (int(yR), int(mR), dia_trans, hora_trans, min_trans, 0, 1, 48, 0)
        t = time.mktime(t)
        val_purchased_at = time.strftime("%Y-%m-%d %H:%M:00", time.localtime(t))
        
        # Valores generados a Insertar a la BD PostgreSQL
        #print(val_customer_id + 1, val_amount, val_purchased_at)
        #print (' ')
       
        # Creación de datos a ingresar a BD:
        datos = (val_customer_id + 1, val_amount, val_purchased_at)
        
        #Inserción de datos de 1000 transacciones generadas aleatoriamente a la BD
        objCursor.execute("INSERT INTO transactions (customer_id, amount, purchased_at) VALUES (%s, %s, %s)",\
                  (datos[0], datos[1], datos[2]))        
        
        # Caso en que se solicite una única transacción:
        if ((x == 1) and (x == (Total_Transactions))):
            datosTMP = '{}{}'.format(datos, ';')
            #datosTMP = (datos)
            
        # Primer valor de los datos, cuando se solicita más de una transacción:
        elif (x == 1):
            datosTMP = '{}{}'.format(datos, ',')
            #datosTMP = (datos)
            
        # Valores anteriores al último dato:
        # Para transacciones mayores a 2:
        elif (x < (Total_Transactions)):
            datos = '{}{}'.format(datos, ',')
            datosTMP = '{}'.format(datosTMP) + '\n' + '{}'.format(datos)
            
        # Último dato: x == transactions            
        else:
            datos = '{}{}'.format(datos, ';')
            datosTMP = '{}'.format(datosTMP) + '\n' + '{}'.format(datos)
            #datosTMP = (datosTMP, datos)
            
        # Valores generados a Insertar a la BD PostgreSQL
        #print(datosTMP)
        #print(' ')
        #print ('***')
        
        
print(' ')
print(datosTMP)
print(' ')
# Out:
# Fecha de Finalización Transacciones:
# 2020-01-13 12:21:00
#
# date and time: 2020-01-13 12:21:24.633017
# time: 12:21:24
# Year: 2020
#
# Month: 01
#
# Day: 13
#
# hour: 12
#
# minute: 21
#
#
#
#
# (3, 298, '2020-01-13 08:00:00'),
# (2, 668, '2020-01-13 08:00:00'),
# (2, 683, '2020-01-13 08:01:00'),
# (2, 891, '2020-01-13 08:02:00'),
# (2, 657, '2020-01-13 08:03:00'),
# (2, 134, '2020-01-13 08:04:00'),
# (1, 545, '2020-01-13 08:00:00'),
# (2, 763, '2020-01-13 08:05:00'),
# (3, 31, '2020-01-13 08:01:00'),
# (4, 130, '2020-01-13 08:00:00'),
# (5, 15, '2020-01-13 08:00:00'),
# (3, 855, '2020-01-13 08:02:00'),
# (2, 87, '2020-01-13 08:06:00'),
# (3, 847, '2020-01-13 08:03:00'),
# (4, 763, '2020-01-13 08:01:00'),
# (4, 973, '2020-01-13 08:02:00'),
# (2, 813, '2020-01-13 08:07:00'),
# (3, 365, '2020-01-13 08:04:00'),
# (2, 499, '2020-01-13 08:08:00'),
# (5, 578, '2020-01-13 08:01:00'),
# (4, 687, '2020-01-13 08:03:00'),
# (3, 910, '2020-01-13 08:05:00'),
# (4, 654, '2020-01-13 08:04:00'),
# (3, 671, '2020-01-13 08:06:00'),
# (1, 355, '2020-01-13 08:01:00'),
# (5, 818, '2020-01-13 08:02:00'),
# (3, 708, '2020-01-13 08:07:00'),
# (4, 568, '2020-01-13 08:05:00'),
# (5, 767, '2020-01-13 08:03:00'),
# (2, 451, '2020-01-13 08:09:00'),
# (4, 549, '2020-01-13 08:06:00'),
# (2, 301, '2020-01-13 08:10:00'),
# (2, 184, '2020-01-13 08:11:00'),
# (5, 365, '2020-01-13 08:04:00'),
# (3, 381, '2020-01-13 08:08:00'),
# (4, 269, '2020-01-13 08:07:00'),
# (5, 287, '2020-01-13 08:05:00'),
# (4, 911, '2020-01-13 08:08:00'),
# (2, 592, '2020-01-13 08:12:00'),
# (4, 564, '2020-01-13 08:09:00'),
# (2, 579, '2020-01-13 08:13:00'),
# (2, 908, '2020-01-13 08:14:00'),
# (2, 719, '2020-01-13 08:15:00'),
# (3, 135, '2020-01-13 08:09:00'),
# (1, 441, '2020-01-13 08:02:00'),
# (4, 400, '2020-01-13 08:10:00'),
# (1, 737, '2020-01-13 08:03:00'),
# (4, 956, '2020-01-13 08:11:00'),
# (1, 231, '2020-01-13 08:04:00'),
# (2, 510, '2020-01-13 08:16:00'),
# (4, 655, '2020-01-13 08:12:00'),
# (3, 164, '2020-01-13 08:10:00'),
# (4, 754, '2020-01-13 08:13:00'),
# (3, 908, '2020-01-13 08:11:00'),
# (3, 208, '2020-01-13 08:12:00'),
# (3, 533, '2020-01-13 08:13:00'),
# (2, 924, '2020-01-13 08:17:00'),
# (5, 244, '2020-01-13 08:06:00'),
# (4, 217, '2020-01-13 08:14:00'),
# (5, 44, '2020-01-13 08:07:00'),
# (5, 719, '2020-01-13 08:08:00'),
# (5, 40, '2020-01-13 08:09:00'),
# (3, 598, '2020-01-13 08:14:00'),
# (5, 350, '2020-01-13 08:10:00'),
# (2, 303, '2020-01-13 08:18:00'),
# (2, 169, '2020-01-13 08:19:00'),
# (5, 115, '2020-01-13 08:11:00'),
# (2, 172, '2020-01-13 08:20:00'),
# (1, 440, '2020-01-13 08:05:00'),
# (5, 570, '2020-01-13 08:12:00'),
# (5, 712, '2020-01-13 08:13:00'),
# (1, 995, '2020-01-13 08:06:00'),
# (4, 846, '2020-01-13 08:15:00'),
# (3, 661, '2020-01-13 08:15:00'),
# (1, 540, '2020-01-13 08:07:00'),
# (1, 130, '2020-01-13 08:08:00'),
# (3, 125, '2020-01-13 08:16:00'),
# (4, 309, '2020-01-13 08:16:00'),
# (3, 579, '2020-01-13 08:17:00'),
# (5, 716, '2020-01-13 08:14:00'),
# (1, 961, '2020-01-13 08:09:00'),
# (4, 535, '2020-01-13 08:17:00'),
# (3, 873, '2020-01-13 08:18:00'),
# (1, 6, '2020-01-13 08:10:00'),
# (3, 343, '2020-01-13 08:19:00'),
# (2, 509, '2020-01-13 08:21:00'),
# (5, 994, '2020-01-13 08:15:00'),
# (5, 530, '2020-01-13 08:16:00'),
# (4, 229, '2020-01-13 08:18:00'),
# (2, 304, '2020-01-13 08:22:00'),
# (1, 386, '2020-01-13 08:11:00'),
# (5, 732, '2020-01-13 08:17:00'),
# (2, 757, '2020-01-13 08:23:00'),
# (2, 265, '2020-01-13 08:24:00'),
# (4, 701, '2020-01-13 08:19:00'),
# (2, 265, '2020-01-13 08:25:00'),
# (4, 603, '2020-01-13 08:20:00'),
# (2, 365, '2020-01-13 08:26:00'),
# (2, 607, '2020-01-13 08:27:00'),
# (3, 439, '2020-01-13 08:20:00'),
# (2, 657, '2020-01-13 08:28:00'),
# (3, 436, '2020-01-13 08:21:00'),
# (1, 325, '2020-01-13 08:12:00'),
# (4, 472, '2020-01-13 08:21:00'),
# (1, 71, '2020-01-13 08:13:00'),
# (1, 615, '2020-01-13 08:14:00'),
# (1, 670, '2020-01-13 08:15:00'),
# (3, 195, '2020-01-13 08:22:00'),
# (4, 493, '2020-01-13 08:22:00'),
# (5, 400, '2020-01-13 08:18:00'),
# (3, 63, '2020-01-13 08:23:00'),
# (3, 541, '2020-01-13 08:24:00'),
# (4, 975, '2020-01-13 08:23:00'),
# (2, 152, '2020-01-13 08:29:00'),
# (1, 115, '2020-01-13 08:16:00'),
# (3, 844, '2020-01-13 08:25:00'),
# (2, 224, '2020-01-13 08:30:00'),
# (3, 311, '2020-01-13 08:26:00'),
# (5, 398, '2020-01-13 08:19:00'),
# (3, 35, '2020-01-13 08:27:00'),
# (3, 132, '2020-01-13 08:28:00'),
# (1, 370, '2020-01-13 08:17:00'),
# (4, 453, '2020-01-13 08:24:00'),
# (5, 898, '2020-01-13 08:20:00'),
# (5, 445, '2020-01-13 08:21:00'),
# (1, 360, '2020-01-13 08:18:00'),
# (5, 303, '2020-01-13 08:22:00'),
# (2, 991, '2020-01-13 08:31:00'),
# (1, 331, '2020-01-13 08:19:00'),
# (2, 915, '2020-01-13 08:32:00'),
# (5, 758, '2020-01-13 08:23:00'),
# (2, 924, '2020-01-13 08:33:00'),
# (1, 917, '2020-01-13 08:20:00'),
# (2, 935, '2020-01-13 08:34:00'),
# (2, 92, '2020-01-13 08:35:00'),
# (4, 955, '2020-01-13 08:25:00'),
# (3, 73, '2020-01-13 08:29:00'),
# (3, 271, '2020-01-13 08:30:00'),
# (2, 49, '2020-01-13 08:36:00'),
# (2, 683, '2020-01-13 08:37:00'),
# (2, 533, '2020-01-13 08:38:00'),
# (4, 200, '2020-01-13 08:26:00'),
# (5, 403, '2020-01-13 08:24:00'),
# (5, 56, '2020-01-13 08:25:00'),
# (5, 920, '2020-01-13 08:26:00'),
# (1, 119, '2020-01-13 08:21:00'),
# (5, 141, '2020-01-13 08:27:00'),
# (5, 779, '2020-01-13 08:28:00'),
# (3, 547, '2020-01-13 08:31:00'),
# (4, 307, '2020-01-13 08:27:00'),
# (2, 985, '2020-01-13 08:39:00'),
# (5, 306, '2020-01-13 08:29:00'),
# (3, 89, '2020-01-13 08:32:00'),
# (3, 54, '2020-01-13 08:33:00'),
# (1, 172, '2020-01-13 08:22:00'),
# (1, 110, '2020-01-13 08:23:00'),
# (5, 734, '2020-01-13 08:30:00'),
# (3, 888, '2020-01-13 08:34:00'),
# (1, 342, '2020-01-13 08:24:00'),
# (4, 165, '2020-01-13 08:28:00'),
# (5, 854, '2020-01-13 08:31:00'),
# (3, 941, '2020-01-13 08:35:00'),
# (1, 113, '2020-01-13 08:25:00'),
# (1, 316, '2020-01-13 08:26:00'),
# (4, 397, '2020-01-13 08:29:00'),
# (4, 400, '2020-01-13 08:30:00'),
# (3, 155, '2020-01-13 08:36:00'),
# (2, 461, '2020-01-13 08:40:00'),
# (3, 4, '2020-01-13 08:37:00'),
# (5, 30, '2020-01-13 08:32:00'),
# (5, 266, '2020-01-13 08:33:00'),
# (3, 340, '2020-01-13 08:38:00'),
# (2, 960, '2020-01-13 08:41:00'),
# (2, 977, '2020-01-13 08:42:00'),
# (3, 427, '2020-01-13 08:39:00'),
# (2, 857, '2020-01-13 08:43:00'),
# (4, 420, '2020-01-13 08:31:00'),
# (3, 159, '2020-01-13 08:40:00'),
# (4, 593, '2020-01-13 08:32:00'),
# (5, 475, '2020-01-13 08:34:00'),
# (2, 785, '2020-01-13 08:44:00'),
# (4, 732, '2020-01-13 08:33:00'),
# (4, 852, '2020-01-13 08:34:00'),
# (2, 30, '2020-01-13 08:45:00'),
# (5, 928, '2020-01-13 08:35:00'),
# (1, 494, '2020-01-13 08:27:00'),
# (5, 184, '2020-01-13 08:36:00'),
# (2, 106, '2020-01-13 08:46:00'),
# (1, 604, '2020-01-13 08:28:00'),
# (2, 315, '2020-01-13 08:47:00'),
# (1, 907, '2020-01-13 08:29:00'),
# (4, 585, '2020-01-13 08:35:00'),
# (5, 743, '2020-01-13 08:37:00'),
# (1, 220, '2020-01-13 08:30:00'),
# (4, 28, '2020-01-13 08:36:00'),
# (5, 23, '2020-01-13 08:38:00'),
# (2, 306, '2020-01-13 08:48:00'),
# (5, 158, '2020-01-13 08:39:00'),
# (1, 750, '2020-01-13 08:31:00'),
# (5, 439, '2020-01-13 08:40:00'),
# (3, 232, '2020-01-13 08:41:00'),
# (4, 23, '2020-01-13 08:37:00'),
# (5, 97, '2020-01-13 08:41:00'),
# (2, 324, '2020-01-13 08:49:00'),
# (5, 517, '2020-01-13 08:42:00'),
# (1, 586, '2020-01-13 08:32:00'),
# (4, 914, '2020-01-13 08:38:00'),
# (3, 669, '2020-01-13 08:42:00'),
# (2, 623, '2020-01-13 08:50:00'),
# (1, 538, '2020-01-13 08:33:00'),
# (4, 242, '2020-01-13 08:39:00'),
# (5, 759, '2020-01-13 08:43:00'),
# (1, 103, '2020-01-13 08:34:00'),
# (3, 937, '2020-01-13 08:43:00'),
# (2, 955, '2020-01-13 08:51:00'),
# (4, 837, '2020-01-13 08:40:00'),
# (3, 852, '2020-01-13 08:44:00'),
# (2, 698, '2020-01-13 08:52:00'),
# (3, 739, '2020-01-13 08:45:00'),
# (2, 684, '2020-01-13 08:53:00'),
# (3, 605, '2020-01-13 08:46:00'),
# (1, 264, '2020-01-13 08:35:00'),
# (2, 129, '2020-01-13 08:54:00'),
# (2, 611, '2020-01-13 08:55:00'),
# (1, 58, '2020-01-13 08:36:00'),
# (5, 658, '2020-01-13 08:44:00'),
# (2, 625, '2020-01-13 08:56:00'),
# (5, 27, '2020-01-13 08:45:00'),
# (4, 898, '2020-01-13 08:41:00'),
# (3, 391, '2020-01-13 08:47:00'),
# (5, 835, '2020-01-13 08:46:00'),
# (5, 512, '2020-01-13 08:47:00'),
# (5, 526, '2020-01-13 08:48:00'),
# (4, 70, '2020-01-13 08:42:00'),
# (4, 540, '2020-01-13 08:43:00'),
# (3, 347, '2020-01-13 08:48:00'),
# (4, 689, '2020-01-13 08:44:00'),
# (1, 935, '2020-01-13 08:37:00'),
# (2, 701, '2020-01-13 08:57:00'),
# (3, 385, '2020-01-13 08:49:00'),
# (5, 80, '2020-01-13 08:49:00'),
# (4, 955, '2020-01-13 08:45:00'),
# (4, 308, '2020-01-13 08:46:00'),
# (1, 731, '2020-01-13 08:38:00'),
# (4, 399, '2020-01-13 08:47:00'),
# (4, 494, '2020-01-13 08:48:00'),
# (5, 916, '2020-01-13 08:50:00'),
# (1, 82, '2020-01-13 08:39:00'),
# (3, 221, '2020-01-13 08:50:00'),
# (1, 150, '2020-01-13 08:40:00'),
# (5, 333, '2020-01-13 08:51:00'),
# (3, 861, '2020-01-13 08:51:00'),
# (5, 213, '2020-01-13 08:52:00'),
# (4, 956, '2020-01-13 08:49:00'),
# (5, 302, '2020-01-13 08:53:00'),
# (1, 209, '2020-01-13 08:41:00'),
# (1, 768, '2020-01-13 08:42:00'),
# (1, 672, '2020-01-13 08:43:00'),
# (2, 979, '2020-01-13 08:58:00'),
# (1, 568, '2020-01-13 08:44:00'),
# (4, 644, '2020-01-13 08:50:00'),
# (2, 321, '2020-01-13 08:59:00'),
# (2, 17, '2020-01-13 09:00:00'),
# (2, 715, '2020-01-13 09:01:00'),
# (2, 51, '2020-01-13 09:02:00'),
# (1, 237, '2020-01-13 08:45:00'),
# (4, 580, '2020-01-13 08:51:00'),
# (2, 676, '2020-01-13 09:03:00'),
# (4, 718, '2020-01-13 08:52:00'),
# (1, 817, '2020-01-13 08:46:00'),
# (4, 874, '2020-01-13 08:53:00'),
# (5, 159, '2020-01-13 08:54:00'),
# (1, 56, '2020-01-13 08:47:00'),
# (3, 636, '2020-01-13 08:52:00'),
# (1, 532, '2020-01-13 08:48:00'),
# (5, 798, '2020-01-13 08:55:00'),
# (2, 94, '2020-01-13 09:04:00'),
# (4, 313, '2020-01-13 08:54:00'),
# (4, 305, '2020-01-13 08:55:00'),
# (2, 269, '2020-01-13 09:05:00'),
# (3, 826, '2020-01-13 08:53:00'),
# (5, 733, '2020-01-13 08:56:00'),
# (5, 428, '2020-01-13 08:57:00'),
# (3, 287, '2020-01-13 08:54:00'),
# (2, 100, '2020-01-13 09:06:00'),
# (1, 165, '2020-01-13 08:49:00'),
# (1, 879, '2020-01-13 08:50:00'),
# (1, 989, '2020-01-13 08:51:00'),
# (3, 154, '2020-01-13 08:55:00'),
# (2, 640, '2020-01-13 09:07:00'),
# (3, 103, '2020-01-13 08:56:00'),
# (1, 505, '2020-01-13 08:52:00'),
# (4, 614, '2020-01-13 08:56:00'),
# (1, 48, '2020-01-13 08:53:00'),
# (5, 559, '2020-01-13 08:58:00'),
# (4, 141, '2020-01-13 08:57:00'),
# (4, 239, '2020-01-13 08:58:00'),
# (4, 340, '2020-01-13 08:59:00'),
# (3, 128, '2020-01-13 08:57:00'),
# (1, 730, '2020-01-13 08:54:00'),
# (4, 91, '2020-01-13 09:00:00'),
# (1, 788, '2020-01-13 08:55:00'),
# (3, 459, '2020-01-13 08:58:00'),
# (1, 432, '2020-01-13 08:56:00'),
# (2, 724, '2020-01-13 09:08:00'),
# (1, 648, '2020-01-13 08:57:00'),
# (5, 144, '2020-01-13 08:59:00'),
# (2, 357, '2020-01-13 09:09:00'),
# (2, 439, '2020-01-13 09:10:00'),
# (4, 20, '2020-01-13 09:01:00'),
# (3, 371, '2020-01-13 08:59:00'),
# (3, 770, '2020-01-13 09:00:00'),
# (3, 765, '2020-01-13 09:01:00'),
# (2, 110, '2020-01-13 09:11:00'),
# (2, 760, '2020-01-13 09:12:00'),
# (2, 577, '2020-01-13 09:13:00'),
# (2, 646, '2020-01-13 09:14:00'),
# (4, 966, '2020-01-13 09:02:00'),
# (1, 818, '2020-01-13 08:58:00'),
# (5, 443, '2020-01-13 09:00:00'),
# (1, 504, '2020-01-13 08:59:00'),
# (4, 565, '2020-01-13 09:03:00'),
# (2, 838, '2020-01-13 09:15:00'),
# (2, 635, '2020-01-13 09:16:00'),
# (4, 819, '2020-01-13 09:04:00'),
# (1, 408, '2020-01-13 09:00:00'),
# (4, 349, '2020-01-13 09:05:00'),
# (4, 410, '2020-01-13 09:06:00'),
# (3, 83, '2020-01-13 09:02:00'),
# (5, 249, '2020-01-13 09:01:00'),
# (4, 173, '2020-01-13 09:07:00'),
# (5, 770, '2020-01-13 09:02:00'),
# (5, 51, '2020-01-13 09:03:00'),
# (4, 452, '2020-01-13 09:08:00'),
# (1, 550, '2020-01-13 09:01:00'),
# (5, 740, '2020-01-13 09:04:00'),
# (4, 762, '2020-01-13 09:09:00'),
# (2, 913, '2020-01-13 09:17:00'),
# (5, 45, '2020-01-13 09:05:00'),
# (5, 741, '2020-01-13 09:06:00'),
# (2, 28, '2020-01-13 09:18:00'),
# (2, 996, '2020-01-13 09:19:00'),
# (4, 46, '2020-01-13 09:10:00'),
# (4, 280, '2020-01-13 09:11:00'),
# (4, 44, '2020-01-13 09:12:00'),
# (3, 196, '2020-01-13 09:03:00'),
# (4, 410, '2020-01-13 09:13:00'),
# (5, 164, '2020-01-13 09:07:00'),
# (4, 790, '2020-01-13 09:14:00'),
# (2, 442, '2020-01-13 09:20:00'),
# (5, 403, '2020-01-13 09:08:00'),
# (1, 401, '2020-01-13 09:02:00'),
# (4, 228, '2020-01-13 09:15:00'),
# (2, 578, '2020-01-13 09:21:00'),
# (4, 210, '2020-01-13 09:16:00'),
# (1, 38, '2020-01-13 09:03:00'),
# (1, 458, '2020-01-13 09:04:00'),
# (5, 742, '2020-01-13 09:09:00'),
# (5, 403, '2020-01-13 09:10:00'),
# (4, 938, '2020-01-13 09:17:00'),
# (5, 136, '2020-01-13 09:11:00'),
# (4, 89, '2020-01-13 09:18:00'),
# (4, 993, '2020-01-13 09:19:00'),
# (4, 601, '2020-01-13 09:20:00'),
# (4, 84, '2020-01-13 09:21:00'),
# (5, 525, '2020-01-13 09:12:00'),
# (5, 14, '2020-01-13 09:13:00'),
# (1, 728, '2020-01-13 09:05:00'),
# (4, 655, '2020-01-13 09:22:00'),
# (2, 246, '2020-01-13 09:22:00'),
# (1, 29, '2020-01-13 09:06:00'),
# (4, 719, '2020-01-13 09:23:00'),
# (5, 892, '2020-01-13 09:14:00'),
# (2, 477, '2020-01-13 09:23:00'),
# (4, 37, '2020-01-13 09:24:00'),
# (4, 849, '2020-01-13 09:25:00'),
# (1, 207, '2020-01-13 09:07:00'),
# (3, 749, '2020-01-13 09:04:00'),
# (4, 539, '2020-01-13 09:26:00'),
# (2, 152, '2020-01-13 09:24:00'),
# (2, 813, '2020-01-13 09:25:00'),
# (1, 182, '2020-01-13 09:08:00'),
# (5, 69, '2020-01-13 09:15:00'),
# (3, 173, '2020-01-13 09:05:00'),
# (4, 985, '2020-01-13 09:27:00'),
# (2, 683, '2020-01-13 09:26:00'),
# (4, 2, '2020-01-13 09:28:00'),
# (5, 735, '2020-01-13 09:16:00'),
# (2, 70, '2020-01-13 09:27:00'),
# (4, 800, '2020-01-13 09:29:00'),
# (1, 67, '2020-01-13 09:09:00'),
# (5, 68, '2020-01-13 09:17:00'),
# (4, 540, '2020-01-13 09:30:00'),
# (2, 197, '2020-01-13 09:28:00'),
# (5, 937, '2020-01-13 09:18:00'),
# (1, 750, '2020-01-13 09:10:00'),
# (1, 391, '2020-01-13 09:11:00'),
# (5, 211, '2020-01-13 09:19:00'),
# (4, 694, '2020-01-13 09:31:00'),
# (3, 147, '2020-01-13 09:06:00'),
# (4, 644, '2020-01-13 09:32:00'),
# (5, 652, '2020-01-13 09:20:00'),
# (2, 904, '2020-01-13 09:29:00'),
# (2, 860, '2020-01-13 09:30:00'),
# (2, 594, '2020-01-13 09:31:00'),
# (5, 961, '2020-01-13 09:21:00'),
# (5, 715, '2020-01-13 09:22:00'),
# (1, 516, '2020-01-13 09:12:00'),
# (4, 525, '2020-01-13 09:33:00'),
# (2, 410, '2020-01-13 09:32:00'),
# (5, 424, '2020-01-13 09:23:00'),
# (2, 797, '2020-01-13 09:33:00'),
# (3, 294, '2020-01-13 09:07:00'),
# (4, 790, '2020-01-13 09:34:00'),
# (1, 110, '2020-01-13 09:13:00'),
# (4, 469, '2020-01-13 09:35:00'),
# (2, 731, '2020-01-13 09:34:00'),
# (2, 271, '2020-01-13 09:35:00'),
# (1, 738, '2020-01-13 09:14:00'),
# (4, 982, '2020-01-13 09:36:00'),
# (2, 574, '2020-01-13 09:36:00'),
# (3, 621, '2020-01-13 09:08:00'),
# (5, 934, '2020-01-13 09:24:00'),
# (5, 920, '2020-01-13 09:25:00'),
# (1, 679, '2020-01-13 09:15:00'),
# (5, 131, '2020-01-13 09:26:00'),
# (4, 339, '2020-01-13 09:37:00'),
# (2, 452, '2020-01-13 09:37:00'),
# (1, 709, '2020-01-13 09:16:00'),
# (4, 278, '2020-01-13 09:38:00'),
# (1, 142, '2020-01-13 09:17:00'),
# (1, 900, '2020-01-13 09:18:00'),
# (3, 453, '2020-01-13 09:09:00'),
# (1, 73, '2020-01-13 09:19:00'),
# (1, 113, '2020-01-13 09:20:00'),
# (3, 87, '2020-01-13 09:10:00'),
# (5, 784, '2020-01-13 09:27:00'),
# (2, 765, '2020-01-13 09:38:00'),
# (5, 498, '2020-01-13 09:28:00'),
# (5, 479, '2020-01-13 09:29:00'),
# (5, 732, '2020-01-13 09:30:00'),
# (1, 478, '2020-01-13 09:21:00'),
# (5, 734, '2020-01-13 09:31:00'),
# (1, 981, '2020-01-13 09:22:00'),
# (5, 348, '2020-01-13 09:32:00'),
# (5, 755, '2020-01-13 09:33:00'),
# (3, 82, '2020-01-13 09:11:00'),
# (4, 783, '2020-01-13 09:39:00'),
# (4, 879, '2020-01-13 09:40:00'),
# (1, 610, '2020-01-13 09:23:00'),
# (2, 974, '2020-01-13 09:39:00'),
# (3, 160, '2020-01-13 09:12:00'),
# (1, 588, '2020-01-13 09:24:00'),
# (2, 77, '2020-01-13 09:40:00'),
# (4, 598, '2020-01-13 09:41:00'),
# (3, 704, '2020-01-13 09:13:00'),
# (4, 293, '2020-01-13 09:42:00'),
# (4, 836, '2020-01-13 09:43:00'),
# (2, 509, '2020-01-13 09:41:00'),
# (2, 106, '2020-01-13 09:42:00'),
# (5, 550, '2020-01-13 09:34:00'),
# (4, 310, '2020-01-13 09:44:00'),
# (1, 80, '2020-01-13 09:25:00'),
# (3, 463, '2020-01-13 09:14:00'),
# (2, 484, '2020-01-13 09:43:00'),
# (1, 700, '2020-01-13 09:26:00'),
# (1, 437, '2020-01-13 09:27:00'),
# (5, 73, '2020-01-13 09:35:00'),
# (4, 627, '2020-01-13 09:45:00'),
# (3, 216, '2020-01-13 09:15:00'),
# (1, 617, '2020-01-13 09:28:00'),
# (5, 707, '2020-01-13 09:36:00'),
# (3, 11, '2020-01-13 09:16:00'),
# (3, 969, '2020-01-13 09:17:00'),
# (4, 22, '2020-01-13 09:46:00'),
# (2, 540, '2020-01-13 09:44:00'),
# (3, 39, '2020-01-13 09:18:00'),
# (3, 761, '2020-01-13 09:19:00'),
# (4, 1, '2020-01-13 09:47:00'),
# (4, 137, '2020-01-13 09:48:00'),
# (4, 52, '2020-01-13 09:49:00'),
# (3, 158, '2020-01-13 09:20:00'),
# (2, 769, '2020-01-13 09:45:00'),
# (3, 789, '2020-01-13 09:21:00'),
# (4, 255, '2020-01-13 09:50:00'),
# (3, 888, '2020-01-13 09:22:00'),
# (5, 492, '2020-01-13 09:37:00'),
# (2, 24, '2020-01-13 09:46:00'),
# (1, 322, '2020-01-13 09:29:00'),
# (2, 58, '2020-01-13 09:47:00'),
# (2, 226, '2020-01-13 09:48:00'),
# (3, 365, '2020-01-13 09:23:00'),
# (5, 851, '2020-01-13 09:38:00'),
# (4, 862, '2020-01-13 09:51:00'),
# (5, 647, '2020-01-13 09:39:00'),
# (3, 12, '2020-01-13 09:24:00'),
# (1, 756, '2020-01-13 09:30:00'),
# (2, 774, '2020-01-13 09:49:00'),
# (3, 994, '2020-01-13 09:25:00'),
# (1, 564, '2020-01-13 09:31:00'),
# (2, 142, '2020-01-13 09:50:00'),
# (1, 427, '2020-01-13 09:32:00'),
# (4, 454, '2020-01-13 09:52:00'),
# (3, 323, '2020-01-13 09:26:00'),
# (5, 262, '2020-01-13 09:40:00'),
# (1, 710, '2020-01-13 09:33:00'),
# (4, 291, '2020-01-13 09:53:00'),
# (2, 886, '2020-01-13 09:51:00'),
# (4, 126, '2020-01-13 09:54:00'),
# (4, 916, '2020-01-13 09:55:00'),
# (2, 108, '2020-01-13 09:52:00'),
# (1, 212, '2020-01-13 09:34:00'),
# (1, 342, '2020-01-13 09:35:00'),
# (2, 173, '2020-01-13 09:53:00'),
# (1, 994, '2020-01-13 09:36:00'),
# (3, 409, '2020-01-13 09:27:00'),
# (2, 195, '2020-01-13 09:54:00'),
# (5, 528, '2020-01-13 09:41:00'),
# (3, 127, '2020-01-13 09:28:00'),
# (1, 698, '2020-01-13 09:37:00'),
# (3, 988, '2020-01-13 09:29:00'),
# (4, 479, '2020-01-13 09:56:00'),
# (4, 397, '2020-01-13 09:57:00'),
# (4, 78, '2020-01-13 09:58:00'),
# (3, 582, '2020-01-13 09:30:00'),
# (4, 521, '2020-01-13 09:59:00'),
# (2, 268, '2020-01-13 09:55:00'),
# (3, 801, '2020-01-13 09:31:00'),
# (4, 492, '2020-01-13 10:00:00'),
# (5, 70, '2020-01-13 09:42:00'),
# (5, 149, '2020-01-13 09:43:00'),
# (1, 362, '2020-01-13 09:38:00'),
# (5, 14, '2020-01-13 09:44:00'),
# (3, 365, '2020-01-13 09:32:00'),
# (4, 594, '2020-01-13 10:01:00'),
# (4, 764, '2020-01-13 10:02:00'),
# (5, 397, '2020-01-13 09:45:00'),
# (2, 111, '2020-01-13 09:56:00'),
# (2, 978, '2020-01-13 09:57:00'),
# (4, 833, '2020-01-13 10:03:00'),
# (5, 107, '2020-01-13 09:46:00'),
# (5, 736, '2020-01-13 09:47:00'),
# (2, 128, '2020-01-13 09:58:00'),
# (4, 420, '2020-01-13 10:04:00'),
# (4, 689, '2020-01-13 10:05:00'),
# (5, 888, '2020-01-13 09:48:00'),
# (2, 413, '2020-01-13 09:59:00'),
# (5, 74, '2020-01-13 09:49:00'),
# (3, 460, '2020-01-13 09:33:00'),
# (4, 8, '2020-01-13 10:06:00'),
# (3, 846, '2020-01-13 09:34:00'),
# (2, 844, '2020-01-13 10:00:00'),
# (3, 510, '2020-01-13 09:35:00'),
# (3, 989, '2020-01-13 09:36:00'),
# (2, 384, '2020-01-13 10:01:00'),
# (3, 741, '2020-01-13 09:37:00'),
# (3, 890, '2020-01-13 09:38:00'),
# (3, 843, '2020-01-13 09:39:00'),
# (2, 45, '2020-01-13 10:02:00'),
# (3, 960, '2020-01-13 09:40:00'),
# (1, 778, '2020-01-13 09:39:00'),
# (2, 991, '2020-01-13 10:03:00'),
# (2, 774, '2020-01-13 10:04:00'),
# (3, 930, '2020-01-13 09:41:00'),
# (3, 884, '2020-01-13 09:42:00'),
# (5, 375, '2020-01-13 09:50:00'),
# (1, 490, '2020-01-13 09:40:00'),
# (1, 182, '2020-01-13 09:41:00'),
# (5, 390, '2020-01-13 09:51:00'),
# (4, 434, '2020-01-13 10:07:00'),
# (3, 426, '2020-01-13 09:43:00'),
# (1, 21, '2020-01-13 09:42:00'),
# (3, 990, '2020-01-13 09:44:00'),
# (2, 245, '2020-01-13 10:05:00'),
# (1, 868, '2020-01-13 09:43:00'),
# (1, 17, '2020-01-13 09:44:00'),
# (1, 425, '2020-01-13 09:45:00'),
# (2, 177, '2020-01-13 10:06:00'),
# (2, 465, '2020-01-13 10:07:00'),
# (2, 989, '2020-01-13 10:08:00'),
# (3, 110, '2020-01-13 09:45:00'),
# (5, 811, '2020-01-13 09:52:00'),
# (4, 538, '2020-01-13 10:08:00'),
# (1, 123, '2020-01-13 09:46:00'),
# (4, 597, '2020-01-13 10:09:00'),
# (5, 920, '2020-01-13 09:53:00'),
# (4, 852, '2020-01-13 10:10:00'),
# (1, 458, '2020-01-13 09:47:00'),
# (3, 65, '2020-01-13 09:46:00'),
# (5, 319, '2020-01-13 09:54:00'),
# (3, 210, '2020-01-13 09:47:00'),
# (1, 492, '2020-01-13 09:48:00'),
# (5, 75, '2020-01-13 09:55:00'),
# (4, 38, '2020-01-13 10:11:00'),
# (3, 750, '2020-01-13 09:48:00'),
# (4, 174, '2020-01-13 10:12:00'),
# (3, 509, '2020-01-13 09:49:00'),
# (2, 617, '2020-01-13 10:09:00'),
# (3, 894, '2020-01-13 09:50:00'),
# (4, 541, '2020-01-13 10:13:00'),
# (4, 750, '2020-01-13 10:14:00'),
# (3, 877, '2020-01-13 09:51:00'),
# (3, 385, '2020-01-13 09:52:00'),
# (2, 331, '2020-01-13 10:10:00'),
# (5, 34, '2020-01-13 09:56:00'),
# (1, 502, '2020-01-13 09:49:00'),
# (2, 844, '2020-01-13 10:11:00'),
# (4, 838, '2020-01-13 10:15:00'),
# (5, 877, '2020-01-13 09:57:00'),
# (3, 354, '2020-01-13 09:53:00'),
# (4, 630, '2020-01-13 10:16:00'),
# (2, 397, '2020-01-13 10:12:00'),
# (5, 666, '2020-01-13 09:58:00'),
# (1, 780, '2020-01-13 09:50:00'),
# (4, 417, '2020-01-13 10:17:00'),
# (5, 911, '2020-01-13 09:59:00'),
# (5, 984, '2020-01-13 10:00:00'),
# (1, 771, '2020-01-13 09:51:00'),
# (3, 286, '2020-01-13 09:54:00'),
# (3, 79, '2020-01-13 09:55:00'),
# (5, 435, '2020-01-13 10:01:00'),
# (1, 565, '2020-01-13 09:52:00'),
# (1, 313, '2020-01-13 09:53:00'),
# (2, 685, '2020-01-13 10:13:00'),
# (2, 76, '2020-01-13 10:14:00'),
# (5, 451, '2020-01-13 10:02:00'),
# (1, 132, '2020-01-13 09:54:00'),
# (4, 500, '2020-01-13 10:18:00'),
# (2, 4, '2020-01-13 10:15:00'),
# (1, 111, '2020-01-13 09:55:00'),
# (2, 937, '2020-01-13 10:16:00'),
# (1, 519, '2020-01-13 09:56:00'),
# (2, 303, '2020-01-13 10:17:00'),
# (3, 39, '2020-01-13 09:56:00'),
# (5, 699, '2020-01-13 10:03:00'),
# (4, 981, '2020-01-13 10:19:00'),
# (4, 102, '2020-01-13 10:20:00'),
# (3, 399, '2020-01-13 09:57:00'),
# (2, 900, '2020-01-13 10:18:00'),
# (1, 935, '2020-01-13 09:57:00'),
# (1, 498, '2020-01-13 09:58:00'),
# (3, 802, '2020-01-13 09:58:00'),
# (4, 535, '2020-01-13 10:21:00'),
# (2, 147, '2020-01-13 10:19:00'),
# (2, 107, '2020-01-13 10:20:00'),
# (1, 688, '2020-01-13 09:59:00'),
# (3, 559, '2020-01-13 09:59:00'),
# (5, 28, '2020-01-13 10:04:00'),
# (1, 277, '2020-01-13 10:00:00'),
# (2, 285, '2020-01-13 10:21:00'),
# (3, 650, '2020-01-13 10:00:00'),
# (5, 393, '2020-01-13 10:05:00'),
# (3, 233, '2020-01-13 10:01:00'),
# (2, 290, '2020-01-13 10:22:00'),
# (5, 231, '2020-01-13 10:06:00'),
# (3, 333, '2020-01-13 10:02:00'),
# (1, 392, '2020-01-13 10:01:00'),
# (2, 890, '2020-01-13 10:23:00'),
# (1, 136, '2020-01-13 10:02:00'),
# (5, 208, '2020-01-13 10:07:00'),
# (5, 480, '2020-01-13 10:08:00'),
# (4, 690, '2020-01-13 10:22:00'),
# (3, 47, '2020-01-13 10:03:00'),
# (1, 59, '2020-01-13 10:03:00'),
# (5, 695, '2020-01-13 10:09:00'),
# (1, 696, '2020-01-13 10:04:00'),
# (3, 932, '2020-01-13 10:04:00'),
# (4, 101, '2020-01-13 10:23:00'),
# (4, 661, '2020-01-13 10:24:00'),
# (5, 964, '2020-01-13 10:10:00'),
# (3, 257, '2020-01-13 10:05:00'),
# (4, 954, '2020-01-13 10:25:00'),
# (5, 27, '2020-01-13 10:11:00'),
# (5, 131, '2020-01-13 10:12:00'),
# (3, 917, '2020-01-13 10:06:00'),
# (5, 298, '2020-01-13 10:13:00'),
# (2, 297, '2020-01-13 10:24:00'),
# (4, 260, '2020-01-13 10:26:00'),
# (3, 429, '2020-01-13 10:07:00'),
# (4, 546, '2020-01-13 10:27:00'),
# (4, 174, '2020-01-13 10:28:00'),
# (2, 65, '2020-01-13 10:25:00'),
# (2, 793, '2020-01-13 10:26:00'),
# (4, 247, '2020-01-13 10:29:00'),
# (5, 869, '2020-01-13 10:14:00'),
# (4, 154, '2020-01-13 10:30:00'),
# (5, 150, '2020-01-13 10:15:00'),
# (1, 334, '2020-01-13 10:05:00'),
# (2, 660, '2020-01-13 10:27:00'),
# (3, 820, '2020-01-13 10:08:00'),
# (1, 712, '2020-01-13 10:06:00'),
# (5, 914, '2020-01-13 10:16:00'),
# (5, 728, '2020-01-13 10:17:00'),
# (5, 461, '2020-01-13 10:18:00'),
# (3, 526, '2020-01-13 10:09:00'),
# (5, 373, '2020-01-13 10:19:00'),
# (1, 214, '2020-01-13 10:07:00'),
# (1, 596, '2020-01-13 10:08:00'),
# (5, 762, '2020-01-13 10:20:00'),
# (4, 516, '2020-01-13 10:31:00'),
# (3, 400, '2020-01-13 10:10:00'),
# (2, 258, '2020-01-13 10:28:00'),
# (5, 866, '2020-01-13 10:21:00'),
# (1, 54, '2020-01-13 10:09:00'),
# (5, 424, '2020-01-13 10:22:00'),
# (2, 333, '2020-01-13 10:29:00'),
# (2, 114, '2020-01-13 10:30:00'),
# (1, 118, '2020-01-13 10:10:00'),
# (5, 742, '2020-01-13 10:23:00'),
# (4, 708, '2020-01-13 10:32:00'),
# (2, 690, '2020-01-13 10:31:00'),
# (2, 880, '2020-01-13 10:32:00'),
# (4, 162, '2020-01-13 10:33:00'),
# (4, 592, '2020-01-13 10:34:00'),
# (3, 727, '2020-01-13 10:11:00'),
# (2, 707, '2020-01-13 10:33:00'),
# (5, 525, '2020-01-13 10:24:00'),
# (1, 47, '2020-01-13 10:11:00'),
# (4, 225, '2020-01-13 10:35:00'),
# (4, 732, '2020-01-13 10:36:00'),
# (2, 773, '2020-01-13 10:34:00'),
# (4, 286, '2020-01-13 10:37:00'),
# (5, 302, '2020-01-13 10:25:00'),
# (2, 686, '2020-01-13 10:35:00'),
# (4, 62, '2020-01-13 10:38:00'),
# (4, 992, '2020-01-13 10:39:00'),
# (3, 524, '2020-01-13 10:12:00'),
# (1, 681, '2020-01-13 10:12:00'),
# (3, 680, '2020-01-13 10:13:00'),
# (3, 664, '2020-01-13 10:14:00'),
# (4, 463, '2020-01-13 10:40:00'),
# (2, 325, '2020-01-13 10:36:00'),
# (2, 340, '2020-01-13 10:37:00'),
# (2, 667, '2020-01-13 10:38:00'),
# (3, 772, '2020-01-13 10:15:00'),
# (2, 322, '2020-01-13 10:39:00'),
# (4, 181, '2020-01-13 10:41:00'),
# (3, 546, '2020-01-13 10:16:00'),
# (3, 479, '2020-01-13 10:17:00'),
# (1, 895, '2020-01-13 10:13:00'),
# (4, 402, '2020-01-13 10:42:00'),
# (3, 951, '2020-01-13 10:18:00'),
# (4, 580, '2020-01-13 10:43:00'),
# (1, 609, '2020-01-13 10:14:00'),
# (4, 46, '2020-01-13 10:44:00'),
# (1, 998, '2020-01-13 10:15:00'),
# (1, 537, '2020-01-13 10:16:00'),
# (5, 716, '2020-01-13 10:26:00'),
# (4, 896, '2020-01-13 10:45:00'),
# (1, 240, '2020-01-13 10:17:00'),
# (1, 93, '2020-01-13 10:18:00'),
# (4, 89, '2020-01-13 10:46:00'),
# (4, 438, '2020-01-13 10:47:00'),
# (5, 284, '2020-01-13 10:27:00'),
# (1, 31, '2020-01-13 10:19:00'),
# (5, 222, '2020-01-13 10:28:00'),
# (3, 512, '2020-01-13 10:19:00'),
# (1, 560, '2020-01-13 10:20:00'),
# (3, 715, '2020-01-13 10:20:00'),
# (3, 976, '2020-01-13 10:21:00'),
# (1, 830, '2020-01-13 10:21:00'),
# (5, 278, '2020-01-13 10:29:00'),
# (2, 604, '2020-01-13 10:40:00'),
# (2, 856, '2020-01-13 10:41:00'),
# (5, 573, '2020-01-13 10:30:00'),
# (4, 220, '2020-01-13 10:48:00'),
# (2, 181, '2020-01-13 10:42:00'),
# (5, 748, '2020-01-13 10:31:00'),
# (2, 260, '2020-01-13 10:43:00'),
# (5, 598, '2020-01-13 10:32:00'),
# (5, 530, '2020-01-13 10:33:00'),
# (4, 205, '2020-01-13 10:49:00'),
# (3, 268, '2020-01-13 10:22:00'),
# (4, 633, '2020-01-13 10:50:00'),
# (1, 368, '2020-01-13 10:22:00'),
# (1, 371, '2020-01-13 10:23:00'),
# (1, 248, '2020-01-13 10:24:00'),
# (3, 256, '2020-01-13 10:23:00'),
# (1, 691, '2020-01-13 10:25:00'),
# (5, 118, '2020-01-13 10:34:00'),
# (3, 906, '2020-01-13 10:24:00'),
# (2, 30, '2020-01-13 10:44:00'),
# (5, 825, '2020-01-13 10:35:00'),
# (5, 664, '2020-01-13 10:36:00'),
# (1, 292, '2020-01-13 10:26:00'),
# (1, 120, '2020-01-13 10:27:00'),
# (2, 178, '2020-01-13 10:45:00'),
# (1, 839, '2020-01-13 10:28:00'),
# (4, 148, '2020-01-13 10:51:00'),
# (3, 693, '2020-01-13 10:25:00'),
# (1, 969, '2020-01-13 10:29:00'),
# (5, 719, '2020-01-13 10:37:00'),
# (1, 738, '2020-01-13 10:30:00'),
# (4, 347, '2020-01-13 10:52:00'),
# (5, 222, '2020-01-13 10:38:00'),
# (5, 349, '2020-01-13 10:39:00'),
# (4, 166, '2020-01-13 10:53:00'),
# (5, 50, '2020-01-13 10:40:00'),
# (3, 361, '2020-01-13 10:26:00'),
# (2, 509, '2020-01-13 10:46:00'),
# (1, 971, '2020-01-13 10:31:00'),
# (5, 50, '2020-01-13 10:41:00'),
# (2, 907, '2020-01-13 10:47:00'),
# (4, 111, '2020-01-13 10:54:00'),
# (1, 78, '2020-01-13 10:32:00'),
# (3, 215, '2020-01-13 10:27:00'),
# (3, 694, '2020-01-13 10:28:00'),
# (4, 485, '2020-01-13 10:55:00'),
# (3, 153, '2020-01-13 10:29:00'),
# (3, 663, '2020-01-13 10:30:00'),
# (5, 821, '2020-01-13 10:42:00'),
# (2, 783, '2020-01-13 10:48:00'),
# (3, 549, '2020-01-13 10:31:00'),
# (1, 462, '2020-01-13 10:33:00'),
# (1, 951, '2020-01-13 10:34:00'),
# (4, 655, '2020-01-13 10:56:00'),
# (1, 370, '2020-01-13 10:35:00'),
# (5, 54, '2020-01-13 10:43:00'),
# (4, 986, '2020-01-13 10:57:00'),
# (5, 497, '2020-01-13 10:44:00'),
# (3, 766, '2020-01-13 10:32:00'),
# (5, 677, '2020-01-13 10:45:00'),
# (1, 251, '2020-01-13 10:36:00'),
# (3, 53, '2020-01-13 10:33:00'),
# (4, 746, '2020-01-13 10:58:00'),
# (4, 475, '2020-01-13 10:59:00'),
# (3, 238, '2020-01-13 10:34:00'),
# (3, 524, '2020-01-13 10:35:00'),
# (1, 291, '2020-01-13 10:37:00'),
# (4, 154, '2020-01-13 11:00:00'),
# (3, 638, '2020-01-13 10:36:00'),
# (3, 604, '2020-01-13 10:37:00'),
# (2, 995, '2020-01-13 10:49:00'),
# (1, 369, '2020-01-13 10:38:00'),
# (5, 956, '2020-01-13 10:46:00'),
# (2, 129, '2020-01-13 10:50:00'),
# (2, 719, '2020-01-13 10:51:00'),
# (5, 118, '2020-01-13 10:47:00'),
# (1, 287, '2020-01-13 10:39:00'),
# (5, 944, '2020-01-13 10:48:00'),
# (5, 805, '2020-01-13 10:49:00'),
# (2, 981, '2020-01-13 10:52:00'),
# (1, 557, '2020-01-13 10:40:00'),
# (4, 864, '2020-01-13 11:01:00'),
# (3, 605, '2020-01-13 10:38:00'),
# (3, 149, '2020-01-13 10:39:00'),
# (4, 390, '2020-01-13 11:02:00'),
# (5, 731, '2020-01-13 10:50:00'),
# (4, 311, '2020-01-13 11:03:00'),
# (2, 116, '2020-01-13 10:53:00'),
# (3, 78, '2020-01-13 10:40:00'),
# (3, 14, '2020-01-13 10:41:00'),
# (2, 570, '2020-01-13 10:54:00'),
# (4, 618, '2020-01-13 11:04:00'),
# (5, 127, '2020-01-13 10:51:00'),
# (4, 212, '2020-01-13 11:05:00'),
# (5, 222, '2020-01-13 10:52:00'),
# (4, 151, '2020-01-13 11:06:00'),
# (3, 255, '2020-01-13 10:42:00'),
# (2, 831, '2020-01-13 10:55:00'),
# (1, 490, '2020-01-13 10:41:00'),
# (1, 394, '2020-01-13 10:42:00'),
# (3, 992, '2020-01-13 10:43:00'),
# (4, 283, '2020-01-13 11:07:00'),
# (2, 545, '2020-01-13 10:56:00'),
# (2, 49, '2020-01-13 10:57:00'),
# (3, 522, '2020-01-13 10:44:00'),
# (2, 46, '2020-01-13 10:58:00'),
# (2, 160, '2020-01-13 10:59:00'),
# (4, 579, '2020-01-13 11:08:00'),
# (3, 851, '2020-01-13 10:45:00'),
# (4, 976, '2020-01-13 11:09:00'),
# (4, 536, '2020-01-13 11:10:00'),
# (5, 233, '2020-01-13 10:53:00'),
# (4, 259, '2020-01-13 11:11:00'),
# (5, 837, '2020-01-13 10:54:00'),
# (2, 148, '2020-01-13 11:00:00'),
# (3, 290, '2020-01-13 10:46:00'),
# (5, 549, '2020-01-13 10:55:00'),
# (1, 941, '2020-01-13 10:43:00'),
# (1, 179, '2020-01-13 10:44:00'),
# (5, 147, '2020-01-13 10:56:00'),
# (5, 274, '2020-01-13 10:57:00'),
# (3, 621, '2020-01-13 10:47:00'),
# (3, 989, '2020-01-13 10:48:00'),
# (3, 782, '2020-01-13 10:49:00'),
# (5, 842, '2020-01-13 10:58:00'),
# (4, 527, '2020-01-13 11:12:00'),
# (4, 160, '2020-01-13 11:13:00'),
# (1, 636, '2020-01-13 10:45:00'),
# (3, 93, '2020-01-13 10:50:00'),
# (4, 572, '2020-01-13 11:14:00'),
# (3, 422, '2020-01-13 10:51:00'),
# (2, 296, '2020-01-13 11:01:00'),
# (5, 771, '2020-01-13 10:59:00'),
# (3, 385, '2020-01-13 10:52:00'),
# (3, 523, '2020-01-13 10:53:00'),
# (5, 390, '2020-01-13 11:00:00'),
# (1, 472, '2020-01-13 10:46:00'),
# (3, 667, '2020-01-13 10:54:00'),
# (5, 936, '2020-01-13 11:01:00'),
# (4, 700, '2020-01-13 11:15:00'),
# (5, 869, '2020-01-13 11:02:00'),
# (4, 247, '2020-01-13 11:16:00'),
# (1, 614, '2020-01-13 10:47:00'),
# (5, 15, '2020-01-13 11:03:00'),
# (2, 624, '2020-01-13 11:02:00'),
# (1, 281, '2020-01-13 10:48:00'),
# (2, 761, '2020-01-13 11:03:00'),
# (2, 141, '2020-01-13 11:04:00'),
# (2, 697, '2020-01-13 11:05:00'),
# (1, 54, '2020-01-13 10:49:00'),
# (2, 50, '2020-01-13 11:06:00'),
# (4, 970, '2020-01-13 11:17:00'),
# (5, 463, '2020-01-13 11:04:00'),
# (3, 369, '2020-01-13 10:55:00'),
# (4, 888, '2020-01-13 11:18:00'),
# (1, 979, '2020-01-13 10:50:00'),
# (2, 406, '2020-01-13 11:07:00'),
# (4, 847, '2020-01-13 11:19:00'),
# (5, 173, '2020-01-13 11:05:00'),
# (4, 359, '2020-01-13 11:20:00'),
# (1, 707, '2020-01-13 10:51:00'),
# (2, 86, '2020-01-13 11:08:00'),
# (3, 699, '2020-01-13 10:56:00'),
# (4, 440, '2020-01-13 11:21:00'),
# (5, 406, '2020-01-13 11:06:00'),
# (5, 604, '2020-01-13 11:07:00'),
# (2, 231, '2020-01-13 11:09:00'),
# (2, 441, '2020-01-13 11:10:00'),
# (3, 890, '2020-01-13 10:57:00'),
# (1, 116, '2020-01-13 10:52:00'),
# (3, 752, '2020-01-13 10:58:00'),
# (1, 226, '2020-01-13 10:53:00'),
# (5, 602, '2020-01-13 11:08:00'),
# (5, 33, '2020-01-13 11:09:00'),
# (1, 217, '2020-01-13 10:54:00'),
# (5, 261, '2020-01-13 11:10:00'),
# (1, 613, '2020-01-13 10:55:00'),
# (2, 597, '2020-01-13 11:11:00'),
# (4, 555, '2020-01-13 11:22:00'),
# (2, 939, '2020-01-13 11:12:00'),
# (5, 868, '2020-01-13 11:11:00'),
# (4, 894, '2020-01-13 11:23:00'),
# (4, 378, '2020-01-13 11:24:00'),
# (3, 460, '2020-01-13 10:59:00'),
# (1, 711, '2020-01-13 10:56:00'),
# (5, 451, '2020-01-13 11:12:00'),
# (1, 818, '2020-01-13 10:57:00'),
# (5, 692, '2020-01-13 11:13:00'),
# (1, 74, '2020-01-13 10:58:00'),
# (1, 885, '2020-01-13 10:59:00'),
# (3, 596, '2020-01-13 11:00:00'),
# (5, 809, '2020-01-13 11:14:00'),
# (4, 874, '2020-01-13 11:25:00'),
# (1, 54, '2020-01-13 11:00:00'),
# (3, 407, '2020-01-13 11:01:00'),
# (4, 604, '2020-01-13 11:26:00'),
# (1, 961, '2020-01-13 11:01:00'),
# (3, 468, '2020-01-13 11:02:00'),
# (3, 528, '2020-01-13 11:03:00'),
# (5, 461, '2020-01-13 11:15:00'),
# (4, 915, '2020-01-13 11:27:00'),
# (5, 383, '2020-01-13 11:16:00'),
# (5, 56, '2020-01-13 11:17:00'),
# (3, 246, '2020-01-13 11:04:00'),
# (5, 332, '2020-01-13 11:18:00'),
# (3, 842, '2020-01-13 11:05:00'),
# (5, 184, '2020-01-13 11:19:00'),
# (4, 426, '2020-01-13 11:28:00'),
# (1, 602, '2020-01-13 11:02:00'),
# (3, 622, '2020-01-13 11:06:00'),
# (2, 228, '2020-01-13 11:13:00'),
# (2, 354, '2020-01-13 11:14:00'),
# (4, 24, '2020-01-13 11:29:00'),
# (4, 158, '2020-01-13 11:30:00'),
# (3, 713, '2020-01-13 11:07:00'),
# (3, 414, '2020-01-13 11:08:00'),
# (5, 141, '2020-01-13 11:20:00'),
# (5, 713, '2020-01-13 11:21:00'),
# (2, 273, '2020-01-13 11:15:00'),
# (1, 701, '2020-01-13 11:03:00'),
# (5, 452, '2020-01-13 11:22:00'),
# (5, 640, '2020-01-13 11:23:00'),
# (5, 615, '2020-01-13 11:24:00'),
# (1, 972, '2020-01-13 11:04:00'),
# (4, 676, '2020-01-13 11:31:00'),
# (2, 274, '2020-01-13 11:16:00'),
# (5, 792, '2020-01-13 11:25:00'),
# (4, 954, '2020-01-13 11:32:00'),
# (5, 751, '2020-01-13 11:26:00'),
# (4, 489, '2020-01-13 11:33:00'),
# (3, 848, '2020-01-13 11:09:00'),
# (1, 291, '2020-01-13 11:05:00'),
# (1, 73, '2020-01-13 11:06:00'),
# (4, 885, '2020-01-13 11:34:00'),
# (5, 810, '2020-01-13 11:27:00'),
# (2, 674, '2020-01-13 11:17:00'),
# (4, 531, '2020-01-13 11:35:00'),
# (3, 464, '2020-01-13 11:10:00');

# %% [markdown]
# ### Verificación de que se ingresó los datos anteriores (1000 transacciones aleatorias) en la tabla "transactions"

# %%
# Consulta a la BD 
objCursor.execute("SELECT * FROM transactions;")
filas = objCursor.fetchall()
filas
# Out:
# [(1, 1, 55, datetime.datetime(2017, 3, 1, 9, 0)),
#  (2, 1, 125, datetime.datetime(2017, 3, 1, 10, 0)),
#  (3, 1, 32, datetime.datetime(2017, 3, 2, 13, 0)),
#  (4, 1, 64, datetime.datetime(2017, 3, 2, 15, 0)),
#  (5, 1, 128, datetime.datetime(2017, 3, 3, 10, 0)),
#  (6, 2, 333, datetime.datetime(2017, 3, 1, 9, 0)),
#  (7, 2, 334, datetime.datetime(2017, 3, 1, 9, 1)),
#  (8, 2, 333, datetime.datetime(2017, 3, 1, 9, 2)),
#  (9, 2, 11, datetime.datetime(2017, 3, 3, 20, 0)),
#  (10, 2, 44, datetime.datetime(2017, 3, 3, 20, 15)),
#  (11, 3, 298, datetime.datetime(2020, 1, 13, 8, 0)),
#  (12, 2, 668, datetime.datetime(2020, 1, 13, 8, 0)),
#  (13, 2, 683, datetime.datetime(2020, 1, 13, 8, 1)),
#  (14, 2, 891, datetime.datetime(2020, 1, 13, 8, 2)),
#  (15, 2, 657, datetime.datetime(2020, 1, 13, 8, 3)),
#  (16, 2, 134, datetime.datetime(2020, 1, 13, 8, 4)),
#  (17, 1, 545, datetime.datetime(2020, 1, 13, 8, 0)),
#  (18, 2, 763, datetime.datetime(2020, 1, 13, 8, 5)),
#  (19, 3, 31, datetime.datetime(2020, 1, 13, 8, 1)),
#  (20, 4, 130, datetime.datetime(2020, 1, 13, 8, 0)),
#  (21, 5, 15, datetime.datetime(2020, 1, 13, 8, 0)),
#  (22, 3, 855, datetime.datetime(2020, 1, 13, 8, 2)),
#  (23, 2, 87, datetime.datetime(2020, 1, 13, 8, 6)),
#  (24, 3, 847, datetime.datetime(2020, 1, 13, 8, 3)),
#  (25, 4, 763, datetime.datetime(2020, 1, 13, 8, 1)),
#  (26, 4, 973, datetime.datetime(2020, 1, 13, 8, 2)),
#  (27, 2, 813, datetime.datetime(2020, 1, 13, 8, 7)),
#  (28, 3, 365, datetime.datetime(2020, 1, 13, 8, 4)),
#  (29, 2, 499, datetime.datetime(2020, 1, 13, 8, 8)),
#  (30, 5, 578, datetime.datetime(2020, 1, 13, 8, 1)),
#  (31, 4, 687, datetime.datetime(2020, 1, 13, 8, 3)),
#  (32, 3, 910, datetime.datetime(2020, 1, 13, 8, 5)),
#  (33, 4, 654, datetime.datetime(2020, 1, 13, 8, 4)),
#  (34, 3, 671, datetime.datetime(2020, 1, 13, 8, 6)),
#  (35, 1, 355, datetime.datetime(2020, 1, 13, 8, 1)),
#  (36, 5, 818, datetime.datetime(2020, 1, 13, 8, 2)),
#  (37, 3, 708, datetime.datetime(2020, 1, 13, 8, 7)),
#  (38, 4, 568, datetime.datetime(2020, 1, 13, 8, 5)),
#  (39, 5, 767, datetime.datetime(2020, 1, 13, 8, 3)),
#  (40, 2, 451, datetime.datetime(2020, 1, 13, 8, 9)),
#  (41, 4, 549, datetime.datetime(2020, 1, 13, 8, 6)),
#  (42, 2, 301, datetime.datetime(2020, 1, 13, 8, 10)),
#  (43, 2, 184, datetime.datetime(2020, 1, 13, 8, 11)),
#  (44, 5, 365, datetime.datetime(2020, 1, 13, 8, 4)),
#  (45, 3, 381, datetime.datetime(2020, 1, 13, 8, 8)),
#  (46, 4, 269, datetime.datetime(2020, 1, 13, 8, 7)),
#  (47, 5, 287, datetime.datetime(2020, 1, 13, 8, 5)),
#  (48, 4, 911, datetime.datetime(2020, 1, 13, 8, 8)),
#  (49, 2, 592, datetime.datetime(2020, 1, 13, 8, 12)),
#  (50, 4, 564, datetime.datetime(2020, 1, 13, 8, 9)),
#  (51, 2, 579, datetime.datetime(2020, 1, 13, 8, 13)),
#  (52, 2, 908, datetime.datetime(2020, 1, 13, 8, 14)),
#  (53, 2, 719, datetime.datetime(2020, 1, 13, 8, 15)),
#  (54, 3, 135, datetime.datetime(2020, 1, 13, 8, 9)),
#  (55, 1, 441, datetime.datetime(2020, 1, 13, 8, 2)),
#  (56, 4, 400, datetime.datetime(2020, 1, 13, 8, 10)),
#  (57, 1, 737, datetime.datetime(2020, 1, 13, 8, 3)),
#  (58, 4, 956, datetime.datetime(2020, 1, 13, 8, 11)),
#  (59, 1, 231, datetime.datetime(2020, 1, 13, 8, 4)),
#  (60, 2, 510, datetime.datetime(2020, 1, 13, 8, 16)),
#  (61, 4, 655, datetime.datetime(2020, 1, 13, 8, 12)),
#  (62, 3, 164, datetime.datetime(2020, 1, 13, 8, 10)),
#  (63, 4, 754, datetime.datetime(2020, 1, 13, 8, 13)),
#  (64, 3, 908, datetime.datetime(2020, 1, 13, 8, 11)),
#  (65, 3, 208, datetime.datetime(2020, 1, 13, 8, 12)),
#  (66, 3, 533, datetime.datetime(2020, 1, 13, 8, 13)),
#  (67, 2, 924, datetime.datetime(2020, 1, 13, 8, 17)),
#  (68, 5, 244, datetime.datetime(2020, 1, 13, 8, 6)),
#  (69, 4, 217, datetime.datetime(2020, 1, 13, 8, 14)),
#  (70, 5, 44, datetime.datetime(2020, 1, 13, 8, 7)),
#  (71, 5, 719, datetime.datetime(2020, 1, 13, 8, 8)),
#  (72, 5, 40, datetime.datetime(2020, 1, 13, 8, 9)),
#  (73, 3, 598, datetime.datetime(2020, 1, 13, 8, 14)),
#  (74, 5, 350, datetime.datetime(2020, 1, 13, 8, 10)),
#  (75, 2, 303, datetime.datetime(2020, 1, 13, 8, 18)),
#  (76, 2, 169, datetime.datetime(2020, 1, 13, 8, 19)),
#  (77, 5, 115, datetime.datetime(2020, 1, 13, 8, 11)),
#  (78, 2, 172, datetime.datetime(2020, 1, 13, 8, 20)),
#  (79, 1, 440, datetime.datetime(2020, 1, 13, 8, 5)),
#  (80, 5, 570, datetime.datetime(2020, 1, 13, 8, 12)),
#  (81, 5, 712, datetime.datetime(2020, 1, 13, 8, 13)),
#  (82, 1, 995, datetime.datetime(2020, 1, 13, 8, 6)),
#  (83, 4, 846, datetime.datetime(2020, 1, 13, 8, 15)),
#  (84, 3, 661, datetime.datetime(2020, 1, 13, 8, 15)),
#  (85, 1, 540, datetime.datetime(2020, 1, 13, 8, 7)),
#  (86, 1, 130, datetime.datetime(2020, 1, 13, 8, 8)),
#  (87, 3, 125, datetime.datetime(2020, 1, 13, 8, 16)),
#  (88, 4, 309, datetime.datetime(2020, 1, 13, 8, 16)),
#  (89, 3, 579, datetime.datetime(2020, 1, 13, 8, 17)),
#  (90, 5, 716, datetime.datetime(2020, 1, 13, 8, 14)),
#  (91, 1, 961, datetime.datetime(2020, 1, 13, 8, 9)),
#  (92, 4, 535, datetime.datetime(2020, 1, 13, 8, 17)),
#  (93, 3, 873, datetime.datetime(2020, 1, 13, 8, 18)),
#  (94, 1, 6, datetime.datetime(2020, 1, 13, 8, 10)),
#  (95, 3, 343, datetime.datetime(2020, 1, 13, 8, 19)),
#  (96, 2, 509, datetime.datetime(2020, 1, 13, 8, 21)),
#  (97, 5, 994, datetime.datetime(2020, 1, 13, 8, 15)),
#  (98, 5, 530, datetime.datetime(2020, 1, 13, 8, 16)),
#  (99, 4, 229, datetime.datetime(2020, 1, 13, 8, 18)),
#  (100, 2, 304, datetime.datetime(2020, 1, 13, 8, 22)),
#  (101, 1, 386, datetime.datetime(2020, 1, 13, 8, 11)),
#  (102, 5, 732, datetime.datetime(2020, 1, 13, 8, 17)),
#  (103, 2, 757, datetime.datetime(2020, 1, 13, 8, 23)),
#  (104, 2, 265, datetime.datetime(2020, 1, 13, 8, 24)),
#  (105, 4, 701, datetime.datetime(2020, 1, 13, 8, 19)),
#  (106, 2, 265, datetime.datetime(2020, 1, 13, 8, 25)),
#  (107, 4, 603, datetime.datetime(2020, 1, 13, 8, 20)),
#  (108, 2, 365, datetime.datetime(2020, 1, 13, 8, 26)),
#  (109, 2, 607, datetime.datetime(2020, 1, 13, 8, 27)),
#  (110, 3, 439, datetime.datetime(2020, 1, 13, 8, 20)),
#  (111, 2, 657, datetime.datetime(2020, 1, 13, 8, 28)),
#  (112, 3, 436, datetime.datetime(2020, 1, 13, 8, 21)),
#  (113, 1, 325, datetime.datetime(2020, 1, 13, 8, 12)),
#  (114, 4, 472, datetime.datetime(2020, 1, 13, 8, 21)),
#  (115, 1, 71, datetime.datetime(2020, 1, 13, 8, 13)),
#  (116, 1, 615, datetime.datetime(2020, 1, 13, 8, 14)),
#  (117, 1, 670, datetime.datetime(2020, 1, 13, 8, 15)),
#  (118, 3, 195, datetime.datetime(2020, 1, 13, 8, 22)),
#  (119, 4, 493, datetime.datetime(2020, 1, 13, 8, 22)),
#  (120, 5, 400, datetime.datetime(2020, 1, 13, 8, 18)),
#  (121, 3, 63, datetime.datetime(2020, 1, 13, 8, 23)),
#  (122, 3, 541, datetime.datetime(2020, 1, 13, 8, 24)),
#  (123, 4, 975, datetime.datetime(2020, 1, 13, 8, 23)),
#  (124, 2, 152, datetime.datetime(2020, 1, 13, 8, 29)),
#  (125, 1, 115, datetime.datetime(2020, 1, 13, 8, 16)),
#  (126, 3, 844, datetime.datetime(2020, 1, 13, 8, 25)),
#  (127, 2, 224, datetime.datetime(2020, 1, 13, 8, 30)),
#  (128, 3, 311, datetime.datetime(2020, 1, 13, 8, 26)),
#  (129, 5, 398, datetime.datetime(2020, 1, 13, 8, 19)),
#  (130, 3, 35, datetime.datetime(2020, 1, 13, 8, 27)),
#  (131, 3, 132, datetime.datetime(2020, 1, 13, 8, 28)),
#  (132, 1, 370, datetime.datetime(2020, 1, 13, 8, 17)),
#  (133, 4, 453, datetime.datetime(2020, 1, 13, 8, 24)),
#  (134, 5, 898, datetime.datetime(2020, 1, 13, 8, 20)),
#  (135, 5, 445, datetime.datetime(2020, 1, 13, 8, 21)),
#  (136, 1, 360, datetime.datetime(2020, 1, 13, 8, 18)),
#  (137, 5, 303, datetime.datetime(2020, 1, 13, 8, 22)),
#  (138, 2, 991, datetime.datetime(2020, 1, 13, 8, 31)),
#  (139, 1, 331, datetime.datetime(2020, 1, 13, 8, 19)),
#  (140, 2, 915, datetime.datetime(2020, 1, 13, 8, 32)),
#  (141, 5, 758, datetime.datetime(2020, 1, 13, 8, 23)),
#  (142, 2, 924, datetime.datetime(2020, 1, 13, 8, 33)),
#  (143, 1, 917, datetime.datetime(2020, 1, 13, 8, 20)),
#  (144, 2, 935, datetime.datetime(2020, 1, 13, 8, 34)),
#  (145, 2, 92, datetime.datetime(2020, 1, 13, 8, 35)),
#  (146, 4, 955, datetime.datetime(2020, 1, 13, 8, 25)),
#  (147, 3, 73, datetime.datetime(2020, 1, 13, 8, 29)),
#  (148, 3, 271, datetime.datetime(2020, 1, 13, 8, 30)),
#  (149, 2, 49, datetime.datetime(2020, 1, 13, 8, 36)),
#  (150, 2, 683, datetime.datetime(2020, 1, 13, 8, 37)),
#  (151, 2, 533, datetime.datetime(2020, 1, 13, 8, 38)),
#  (152, 4, 200, datetime.datetime(2020, 1, 13, 8, 26)),
#  (153, 5, 403, datetime.datetime(2020, 1, 13, 8, 24)),
#  (154, 5, 56, datetime.datetime(2020, 1, 13, 8, 25)),
#  (155, 5, 920, datetime.datetime(2020, 1, 13, 8, 26)),
#  (156, 1, 119, datetime.datetime(2020, 1, 13, 8, 21)),
#  (157, 5, 141, datetime.datetime(2020, 1, 13, 8, 27)),
#  (158, 5, 779, datetime.datetime(2020, 1, 13, 8, 28)),
#  (159, 3, 547, datetime.datetime(2020, 1, 13, 8, 31)),
#  (160, 4, 307, datetime.datetime(2020, 1, 13, 8, 27)),
#  (161, 2, 985, datetime.datetime(2020, 1, 13, 8, 39)),
#  (162, 5, 306, datetime.datetime(2020, 1, 13, 8, 29)),
#  (163, 3, 89, datetime.datetime(2020, 1, 13, 8, 32)),
#  (164, 3, 54, datetime.datetime(2020, 1, 13, 8, 33)),
#  (165, 1, 172, datetime.datetime(2020, 1, 13, 8, 22)),
#  (166, 1, 110, datetime.datetime(2020, 1, 13, 8, 23)),
#  (167, 5, 734, datetime.datetime(2020, 1, 13, 8, 30)),
#  (168, 3, 888, datetime.datetime(2020, 1, 13, 8, 34)),
#  (169, 1, 342, datetime.datetime(2020, 1, 13, 8, 24)),
#  (170, 4, 165, datetime.datetime(2020, 1, 13, 8, 28)),
#  (171, 5, 854, datetime.datetime(2020, 1, 13, 8, 31)),
#  (172, 3, 941, datetime.datetime(2020, 1, 13, 8, 35)),
#  (173, 1, 113, datetime.datetime(2020, 1, 13, 8, 25)),
#  (174, 1, 316, datetime.datetime(2020, 1, 13, 8, 26)),
#  (175, 4, 397, datetime.datetime(2020, 1, 13, 8, 29)),
#  (176, 4, 400, datetime.datetime(2020, 1, 13, 8, 30)),
#  (177, 3, 155, datetime.datetime(2020, 1, 13, 8, 36)),
#  (178, 2, 461, datetime.datetime(2020, 1, 13, 8, 40)),
#  (179, 3, 4, datetime.datetime(2020, 1, 13, 8, 37)),
#  (180, 5, 30, datetime.datetime(2020, 1, 13, 8, 32)),
#  (181, 5, 266, datetime.datetime(2020, 1, 13, 8, 33)),
#  (182, 3, 340, datetime.datetime(2020, 1, 13, 8, 38)),
#  (183, 2, 960, datetime.datetime(2020, 1, 13, 8, 41)),
#  (184, 2, 977, datetime.datetime(2020, 1, 13, 8, 42)),
#  (185, 3, 427, datetime.datetime(2020, 1, 13, 8, 39)),
#  (186, 2, 857, datetime.datetime(2020, 1, 13, 8, 43)),
#  (187, 4, 420, datetime.datetime(2020, 1, 13, 8, 31)),
#  (188, 3, 159, datetime.datetime(2020, 1, 13, 8, 40)),
#  (189, 4, 593, datetime.datetime(2020, 1, 13, 8, 32)),
#  (190, 5, 475, datetime.datetime(2020, 1, 13, 8, 34)),
#  (191, 2, 785, datetime.datetime(2020, 1, 13, 8, 44)),
#  (192, 4, 732, datetime.datetime(2020, 1, 13, 8, 33)),
#  (193, 4, 852, datetime.datetime(2020, 1, 13, 8, 34)),
#  (194, 2, 30, datetime.datetime(2020, 1, 13, 8, 45)),
#  (195, 5, 928, datetime.datetime(2020, 1, 13, 8, 35)),
#  (196, 1, 494, datetime.datetime(2020, 1, 13, 8, 27)),
#  (197, 5, 184, datetime.datetime(2020, 1, 13, 8, 36)),
#  (198, 2, 106, datetime.datetime(2020, 1, 13, 8, 46)),
#  (199, 1, 604, datetime.datetime(2020, 1, 13, 8, 28)),
#  (200, 2, 315, datetime.datetime(2020, 1, 13, 8, 47)),
#  (201, 1, 907, datetime.datetime(2020, 1, 13, 8, 29)),
#  (202, 4, 585, datetime.datetime(2020, 1, 13, 8, 35)),
#  (203, 5, 743, datetime.datetime(2020, 1, 13, 8, 37)),
#  (204, 1, 220, datetime.datetime(2020, 1, 13, 8, 30)),
#  (205, 4, 28, datetime.datetime(2020, 1, 13, 8, 36)),
#  (206, 5, 23, datetime.datetime(2020, 1, 13, 8, 38)),
#  (207, 2, 306, datetime.datetime(2020, 1, 13, 8, 48)),
#  (208, 5, 158, datetime.datetime(2020, 1, 13, 8, 39)),
#  (209, 1, 750, datetime.datetime(2020, 1, 13, 8, 31)),
#  (210, 5, 439, datetime.datetime(2020, 1, 13, 8, 40)),
#  (211, 3, 232, datetime.datetime(2020, 1, 13, 8, 41)),
#  (212, 4, 23, datetime.datetime(2020, 1, 13, 8, 37)),
#  (213, 5, 97, datetime.datetime(2020, 1, 13, 8, 41)),
#  (214, 2, 324, datetime.datetime(2020, 1, 13, 8, 49)),
#  (215, 5, 517, datetime.datetime(2020, 1, 13, 8, 42)),
#  (216, 1, 586, datetime.datetime(2020, 1, 13, 8, 32)),
#  (217, 4, 914, datetime.datetime(2020, 1, 13, 8, 38)),
#  (218, 3, 669, datetime.datetime(2020, 1, 13, 8, 42)),
#  (219, 2, 623, datetime.datetime(2020, 1, 13, 8, 50)),
#  (220, 1, 538, datetime.datetime(2020, 1, 13, 8, 33)),
#  (221, 4, 242, datetime.datetime(2020, 1, 13, 8, 39)),
#  (222, 5, 759, datetime.datetime(2020, 1, 13, 8, 43)),
#  (223, 1, 103, datetime.datetime(2020, 1, 13, 8, 34)),
#  (224, 3, 937, datetime.datetime(2020, 1, 13, 8, 43)),
#  (225, 2, 955, datetime.datetime(2020, 1, 13, 8, 51)),
#  (226, 4, 837, datetime.datetime(2020, 1, 13, 8, 40)),
#  (227, 3, 852, datetime.datetime(2020, 1, 13, 8, 44)),
#  (228, 2, 698, datetime.datetime(2020, 1, 13, 8, 52)),
#  (229, 3, 739, datetime.datetime(2020, 1, 13, 8, 45)),
#  (230, 2, 684, datetime.datetime(2020, 1, 13, 8, 53)),
#  (231, 3, 605, datetime.datetime(2020, 1, 13, 8, 46)),
#  (232, 1, 264, datetime.datetime(2020, 1, 13, 8, 35)),
#  (233, 2, 129, datetime.datetime(2020, 1, 13, 8, 54)),
#  (234, 2, 611, datetime.datetime(2020, 1, 13, 8, 55)),
#  (235, 1, 58, datetime.datetime(2020, 1, 13, 8, 36)),
#  (236, 5, 658, datetime.datetime(2020, 1, 13, 8, 44)),
#  (237, 2, 625, datetime.datetime(2020, 1, 13, 8, 56)),
#  (238, 5, 27, datetime.datetime(2020, 1, 13, 8, 45)),
#  (239, 4, 898, datetime.datetime(2020, 1, 13, 8, 41)),
#  (240, 3, 391, datetime.datetime(2020, 1, 13, 8, 47)),
#  (241, 5, 835, datetime.datetime(2020, 1, 13, 8, 46)),
#  (242, 5, 512, datetime.datetime(2020, 1, 13, 8, 47)),
#  (243, 5, 526, datetime.datetime(2020, 1, 13, 8, 48)),
#  (244, 4, 70, datetime.datetime(2020, 1, 13, 8, 42)),
#  (245, 4, 540, datetime.datetime(2020, 1, 13, 8, 43)),
#  (246, 3, 347, datetime.datetime(2020, 1, 13, 8, 48)),
#  (247, 4, 689, datetime.datetime(2020, 1, 13, 8, 44)),
#  (248, 1, 935, datetime.datetime(2020, 1, 13, 8, 37)),
#  (249, 2, 701, datetime.datetime(2020, 1, 13, 8, 57)),
#  (250, 3, 385, datetime.datetime(2020, 1, 13, 8, 49)),
#  (251, 5, 80, datetime.datetime(2020, 1, 13, 8, 49)),
#  (252, 4, 955, datetime.datetime(2020, 1, 13, 8, 45)),
#  (253, 4, 308, datetime.datetime(2020, 1, 13, 8, 46)),
#  (254, 1, 731, datetime.datetime(2020, 1, 13, 8, 38)),
#  (255, 4, 399, datetime.datetime(2020, 1, 13, 8, 47)),
#  (256, 4, 494, datetime.datetime(2020, 1, 13, 8, 48)),
#  (257, 5, 916, datetime.datetime(2020, 1, 13, 8, 50)),
#  (258, 1, 82, datetime.datetime(2020, 1, 13, 8, 39)),
#  (259, 3, 221, datetime.datetime(2020, 1, 13, 8, 50)),
#  (260, 1, 150, datetime.datetime(2020, 1, 13, 8, 40)),
#  (261, 5, 333, datetime.datetime(2020, 1, 13, 8, 51)),
#  (262, 3, 861, datetime.datetime(2020, 1, 13, 8, 51)),
#  (263, 5, 213, datetime.datetime(2020, 1, 13, 8, 52)),
#  (264, 4, 956, datetime.datetime(2020, 1, 13, 8, 49)),
#  (265, 5, 302, datetime.datetime(2020, 1, 13, 8, 53)),
#  (266, 1, 209, datetime.datetime(2020, 1, 13, 8, 41)),
#  (267, 1, 768, datetime.datetime(2020, 1, 13, 8, 42)),
#  (268, 1, 672, datetime.datetime(2020, 1, 13, 8, 43)),
#  (269, 2, 979, datetime.datetime(2020, 1, 13, 8, 58)),
#  (270, 1, 568, datetime.datetime(2020, 1, 13, 8, 44)),
#  (271, 4, 644, datetime.datetime(2020, 1, 13, 8, 50)),
#  (272, 2, 321, datetime.datetime(2020, 1, 13, 8, 59)),
#  (273, 2, 17, datetime.datetime(2020, 1, 13, 9, 0)),
#  (274, 2, 715, datetime.datetime(2020, 1, 13, 9, 1)),
#  (275, 2, 51, datetime.datetime(2020, 1, 13, 9, 2)),
#  (276, 1, 237, datetime.datetime(2020, 1, 13, 8, 45)),
#  (277, 4, 580, datetime.datetime(2020, 1, 13, 8, 51)),
#  (278, 2, 676, datetime.datetime(2020, 1, 13, 9, 3)),
#  (279, 4, 718, datetime.datetime(2020, 1, 13, 8, 52)),
#  (280, 1, 817, datetime.datetime(2020, 1, 13, 8, 46)),
#  (281, 4, 874, datetime.datetime(2020, 1, 13, 8, 53)),
#  (282, 5, 159, datetime.datetime(2020, 1, 13, 8, 54)),
#  (283, 1, 56, datetime.datetime(2020, 1, 13, 8, 47)),
#  (284, 3, 636, datetime.datetime(2020, 1, 13, 8, 52)),
#  (285, 1, 532, datetime.datetime(2020, 1, 13, 8, 48)),
#  (286, 5, 798, datetime.datetime(2020, 1, 13, 8, 55)),
#  (287, 2, 94, datetime.datetime(2020, 1, 13, 9, 4)),
#  (288, 4, 313, datetime.datetime(2020, 1, 13, 8, 54)),
#  (289, 4, 305, datetime.datetime(2020, 1, 13, 8, 55)),
#  (290, 2, 269, datetime.datetime(2020, 1, 13, 9, 5)),
#  (291, 3, 826, datetime.datetime(2020, 1, 13, 8, 53)),
#  (292, 5, 733, datetime.datetime(2020, 1, 13, 8, 56)),
#  (293, 5, 428, datetime.datetime(2020, 1, 13, 8, 57)),
#  (294, 3, 287, datetime.datetime(2020, 1, 13, 8, 54)),
#  (295, 2, 100, datetime.datetime(2020, 1, 13, 9, 6)),
#  (296, 1, 165, datetime.datetime(2020, 1, 13, 8, 49)),
#  (297, 1, 879, datetime.datetime(2020, 1, 13, 8, 50)),
#  (298, 1, 989, datetime.datetime(2020, 1, 13, 8, 51)),
#  (299, 3, 154, datetime.datetime(2020, 1, 13, 8, 55)),
#  (300, 2, 640, datetime.datetime(2020, 1, 13, 9, 7)),
#  (301, 3, 103, datetime.datetime(2020, 1, 13, 8, 56)),
#  (302, 1, 505, datetime.datetime(2020, 1, 13, 8, 52)),
#  (303, 4, 614, datetime.datetime(2020, 1, 13, 8, 56)),
#  (304, 1, 48, datetime.datetime(2020, 1, 13, 8, 53)),
#  (305, 5, 559, datetime.datetime(2020, 1, 13, 8, 58)),
#  (306, 4, 141, datetime.datetime(2020, 1, 13, 8, 57)),
#  (307, 4, 239, datetime.datetime(2020, 1, 13, 8, 58)),
#  (308, 4, 340, datetime.datetime(2020, 1, 13, 8, 59)),
#  (309, 3, 128, datetime.datetime(2020, 1, 13, 8, 57)),
#  (310, 1, 730, datetime.datetime(2020, 1, 13, 8, 54)),
#  (311, 4, 91, datetime.datetime(2020, 1, 13, 9, 0)),
#  (312, 1, 788, datetime.datetime(2020, 1, 13, 8, 55)),
#  (313, 3, 459, datetime.datetime(2020, 1, 13, 8, 58)),
#  (314, 1, 432, datetime.datetime(2020, 1, 13, 8, 56)),
#  (315, 2, 724, datetime.datetime(2020, 1, 13, 9, 8)),
#  (316, 1, 648, datetime.datetime(2020, 1, 13, 8, 57)),
#  (317, 5, 144, datetime.datetime(2020, 1, 13, 8, 59)),
#  (318, 2, 357, datetime.datetime(2020, 1, 13, 9, 9)),
#  (319, 2, 439, datetime.datetime(2020, 1, 13, 9, 10)),
#  (320, 4, 20, datetime.datetime(2020, 1, 13, 9, 1)),
#  (321, 3, 371, datetime.datetime(2020, 1, 13, 8, 59)),
#  (322, 3, 770, datetime.datetime(2020, 1, 13, 9, 0)),
#  (323, 3, 765, datetime.datetime(2020, 1, 13, 9, 1)),
#  (324, 2, 110, datetime.datetime(2020, 1, 13, 9, 11)),
#  (325, 2, 760, datetime.datetime(2020, 1, 13, 9, 12)),
#  (326, 2, 577, datetime.datetime(2020, 1, 13, 9, 13)),
#  (327, 2, 646, datetime.datetime(2020, 1, 13, 9, 14)),
#  (328, 4, 966, datetime.datetime(2020, 1, 13, 9, 2)),
#  (329, 1, 818, datetime.datetime(2020, 1, 13, 8, 58)),
#  (330, 5, 443, datetime.datetime(2020, 1, 13, 9, 0)),
#  (331, 1, 504, datetime.datetime(2020, 1, 13, 8, 59)),
#  (332, 4, 565, datetime.datetime(2020, 1, 13, 9, 3)),
#  (333, 2, 838, datetime.datetime(2020, 1, 13, 9, 15)),
#  (334, 2, 635, datetime.datetime(2020, 1, 13, 9, 16)),
#  (335, 4, 819, datetime.datetime(2020, 1, 13, 9, 4)),
#  (336, 1, 408, datetime.datetime(2020, 1, 13, 9, 0)),
#  (337, 4, 349, datetime.datetime(2020, 1, 13, 9, 5)),
#  (338, 4, 410, datetime.datetime(2020, 1, 13, 9, 6)),
#  (339, 3, 83, datetime.datetime(2020, 1, 13, 9, 2)),
#  (340, 5, 249, datetime.datetime(2020, 1, 13, 9, 1)),
#  (341, 4, 173, datetime.datetime(2020, 1, 13, 9, 7)),
#  (342, 5, 770, datetime.datetime(2020, 1, 13, 9, 2)),
#  (343, 5, 51, datetime.datetime(2020, 1, 13, 9, 3)),
#  (344, 4, 452, datetime.datetime(2020, 1, 13, 9, 8)),
#  (345, 1, 550, datetime.datetime(2020, 1, 13, 9, 1)),
#  (346, 5, 740, datetime.datetime(2020, 1, 13, 9, 4)),
#  (347, 4, 762, datetime.datetime(2020, 1, 13, 9, 9)),
#  (348, 2, 913, datetime.datetime(2020, 1, 13, 9, 17)),
#  (349, 5, 45, datetime.datetime(2020, 1, 13, 9, 5)),
#  (350, 5, 741, datetime.datetime(2020, 1, 13, 9, 6)),
#  (351, 2, 28, datetime.datetime(2020, 1, 13, 9, 18)),
#  (352, 2, 996, datetime.datetime(2020, 1, 13, 9, 19)),
#  (353, 4, 46, datetime.datetime(2020, 1, 13, 9, 10)),
#  (354, 4, 280, datetime.datetime(2020, 1, 13, 9, 11)),
#  (355, 4, 44, datetime.datetime(2020, 1, 13, 9, 12)),
#  (356, 3, 196, datetime.datetime(2020, 1, 13, 9, 3)),
#  (357, 4, 410, datetime.datetime(2020, 1, 13, 9, 13)),
#  (358, 5, 164, datetime.datetime(2020, 1, 13, 9, 7)),
#  (359, 4, 790, datetime.datetime(2020, 1, 13, 9, 14)),
#  (360, 2, 442, datetime.datetime(2020, 1, 13, 9, 20)),
#  (361, 5, 403, datetime.datetime(2020, 1, 13, 9, 8)),
#  (362, 1, 401, datetime.datetime(2020, 1, 13, 9, 2)),
#  (363, 4, 228, datetime.datetime(2020, 1, 13, 9, 15)),
#  (364, 2, 578, datetime.datetime(2020, 1, 13, 9, 21)),
#  (365, 4, 210, datetime.datetime(2020, 1, 13, 9, 16)),
#  (366, 1, 38, datetime.datetime(2020, 1, 13, 9, 3)),
#  (367, 1, 458, datetime.datetime(2020, 1, 13, 9, 4)),
#  (368, 5, 742, datetime.datetime(2020, 1, 13, 9, 9)),
#  (369, 5, 403, datetime.datetime(2020, 1, 13, 9, 10)),
#  (370, 4, 938, datetime.datetime(2020, 1, 13, 9, 17)),
#  (371, 5, 136, datetime.datetime(2020, 1, 13, 9, 11)),
#  (372, 4, 89, datetime.datetime(2020, 1, 13, 9, 18)),
#  (373, 4, 993, datetime.datetime(2020, 1, 13, 9, 19)),
#  (374, 4, 601, datetime.datetime(2020, 1, 13, 9, 20)),
#  (375, 4, 84, datetime.datetime(2020, 1, 13, 9, 21)),
#  (376, 5, 525, datetime.datetime(2020, 1, 13, 9, 12)),
#  (377, 5, 14, datetime.datetime(2020, 1, 13, 9, 13)),
#  (378, 1, 728, datetime.datetime(2020, 1, 13, 9, 5)),
#  (379, 4, 655, datetime.datetime(2020, 1, 13, 9, 22)),
#  (380, 2, 246, datetime.datetime(2020, 1, 13, 9, 22)),
#  (381, 1, 29, datetime.datetime(2020, 1, 13, 9, 6)),
#  (382, 4, 719, datetime.datetime(2020, 1, 13, 9, 23)),
#  (383, 5, 892, datetime.datetime(2020, 1, 13, 9, 14)),
#  (384, 2, 477, datetime.datetime(2020, 1, 13, 9, 23)),
#  (385, 4, 37, datetime.datetime(2020, 1, 13, 9, 24)),
#  (386, 4, 849, datetime.datetime(2020, 1, 13, 9, 25)),
#  (387, 1, 207, datetime.datetime(2020, 1, 13, 9, 7)),
#  (388, 3, 749, datetime.datetime(2020, 1, 13, 9, 4)),
#  (389, 4, 539, datetime.datetime(2020, 1, 13, 9, 26)),
#  (390, 2, 152, datetime.datetime(2020, 1, 13, 9, 24)),
#  (391, 2, 813, datetime.datetime(2020, 1, 13, 9, 25)),
#  (392, 1, 182, datetime.datetime(2020, 1, 13, 9, 8)),
#  (393, 5, 69, datetime.datetime(2020, 1, 13, 9, 15)),
#  (394, 3, 173, datetime.datetime(2020, 1, 13, 9, 5)),
#  (395, 4, 985, datetime.datetime(2020, 1, 13, 9, 27)),
#  (396, 2, 683, datetime.datetime(2020, 1, 13, 9, 26)),
#  (397, 4, 2, datetime.datetime(2020, 1, 13, 9, 28)),
#  (398, 5, 735, datetime.datetime(2020, 1, 13, 9, 16)),
#  (399, 2, 70, datetime.datetime(2020, 1, 13, 9, 27)),
#  (400, 4, 800, datetime.datetime(2020, 1, 13, 9, 29)),
#  (401, 1, 67, datetime.datetime(2020, 1, 13, 9, 9)),
#  (402, 5, 68, datetime.datetime(2020, 1, 13, 9, 17)),
#  (403, 4, 540, datetime.datetime(2020, 1, 13, 9, 30)),
#  (404, 2, 197, datetime.datetime(2020, 1, 13, 9, 28)),
#  (405, 5, 937, datetime.datetime(2020, 1, 13, 9, 18)),
#  (406, 1, 750, datetime.datetime(2020, 1, 13, 9, 10)),
#  (407, 1, 391, datetime.datetime(2020, 1, 13, 9, 11)),
#  (408, 5, 211, datetime.datetime(2020, 1, 13, 9, 19)),
#  (409, 4, 694, datetime.datetime(2020, 1, 13, 9, 31)),
#  (410, 3, 147, datetime.datetime(2020, 1, 13, 9, 6)),
#  (411, 4, 644, datetime.datetime(2020, 1, 13, 9, 32)),
#  (412, 5, 652, datetime.datetime(2020, 1, 13, 9, 20)),
#  (413, 2, 904, datetime.datetime(2020, 1, 13, 9, 29)),
#  (414, 2, 860, datetime.datetime(2020, 1, 13, 9, 30)),
#  (415, 2, 594, datetime.datetime(2020, 1, 13, 9, 31)),
#  (416, 5, 961, datetime.datetime(2020, 1, 13, 9, 21)),
#  (417, 5, 715, datetime.datetime(2020, 1, 13, 9, 22)),
#  (418, 1, 516, datetime.datetime(2020, 1, 13, 9, 12)),
#  (419, 4, 525, datetime.datetime(2020, 1, 13, 9, 33)),
#  (420, 2, 410, datetime.datetime(2020, 1, 13, 9, 32)),
#  (421, 5, 424, datetime.datetime(2020, 1, 13, 9, 23)),
#  (422, 2, 797, datetime.datetime(2020, 1, 13, 9, 33)),
#  (423, 3, 294, datetime.datetime(2020, 1, 13, 9, 7)),
#  (424, 4, 790, datetime.datetime(2020, 1, 13, 9, 34)),
#  (425, 1, 110, datetime.datetime(2020, 1, 13, 9, 13)),
#  (426, 4, 469, datetime.datetime(2020, 1, 13, 9, 35)),
#  (427, 2, 731, datetime.datetime(2020, 1, 13, 9, 34)),
#  (428, 2, 271, datetime.datetime(2020, 1, 13, 9, 35)),
#  (429, 1, 738, datetime.datetime(2020, 1, 13, 9, 14)),
#  (430, 4, 982, datetime.datetime(2020, 1, 13, 9, 36)),
#  (431, 2, 574, datetime.datetime(2020, 1, 13, 9, 36)),
#  (432, 3, 621, datetime.datetime(2020, 1, 13, 9, 8)),
#  (433, 5, 934, datetime.datetime(2020, 1, 13, 9, 24)),
#  (434, 5, 920, datetime.datetime(2020, 1, 13, 9, 25)),
#  (435, 1, 679, datetime.datetime(2020, 1, 13, 9, 15)),
#  (436, 5, 131, datetime.datetime(2020, 1, 13, 9, 26)),
#  (437, 4, 339, datetime.datetime(2020, 1, 13, 9, 37)),
#  (438, 2, 452, datetime.datetime(2020, 1, 13, 9, 37)),
#  (439, 1, 709, datetime.datetime(2020, 1, 13, 9, 16)),
#  (440, 4, 278, datetime.datetime(2020, 1, 13, 9, 38)),
#  (441, 1, 142, datetime.datetime(2020, 1, 13, 9, 17)),
#  (442, 1, 900, datetime.datetime(2020, 1, 13, 9, 18)),
#  (443, 3, 453, datetime.datetime(2020, 1, 13, 9, 9)),
#  (444, 1, 73, datetime.datetime(2020, 1, 13, 9, 19)),
#  (445, 1, 113, datetime.datetime(2020, 1, 13, 9, 20)),
#  (446, 3, 87, datetime.datetime(2020, 1, 13, 9, 10)),
#  (447, 5, 784, datetime.datetime(2020, 1, 13, 9, 27)),
#  (448, 2, 765, datetime.datetime(2020, 1, 13, 9, 38)),
#  (449, 5, 498, datetime.datetime(2020, 1, 13, 9, 28)),
#  (450, 5, 479, datetime.datetime(2020, 1, 13, 9, 29)),
#  (451, 5, 732, datetime.datetime(2020, 1, 13, 9, 30)),
#  (452, 1, 478, datetime.datetime(2020, 1, 13, 9, 21)),
#  (453, 5, 734, datetime.datetime(2020, 1, 13, 9, 31)),
#  (454, 1, 981, datetime.datetime(2020, 1, 13, 9, 22)),
#  (455, 5, 348, datetime.datetime(2020, 1, 13, 9, 32)),
#  (456, 5, 755, datetime.datetime(2020, 1, 13, 9, 33)),
#  (457, 3, 82, datetime.datetime(2020, 1, 13, 9, 11)),
#  (458, 4, 783, datetime.datetime(2020, 1, 13, 9, 39)),
#  (459, 4, 879, datetime.datetime(2020, 1, 13, 9, 40)),
#  (460, 1, 610, datetime.datetime(2020, 1, 13, 9, 23)),
#  (461, 2, 974, datetime.datetime(2020, 1, 13, 9, 39)),
#  (462, 3, 160, datetime.datetime(2020, 1, 13, 9, 12)),
#  (463, 1, 588, datetime.datetime(2020, 1, 13, 9, 24)),
#  (464, 2, 77, datetime.datetime(2020, 1, 13, 9, 40)),
#  (465, 4, 598, datetime.datetime(2020, 1, 13, 9, 41)),
#  (466, 3, 704, datetime.datetime(2020, 1, 13, 9, 13)),
#  (467, 4, 293, datetime.datetime(2020, 1, 13, 9, 42)),
#  (468, 4, 836, datetime.datetime(2020, 1, 13, 9, 43)),
#  (469, 2, 509, datetime.datetime(2020, 1, 13, 9, 41)),
#  (470, 2, 106, datetime.datetime(2020, 1, 13, 9, 42)),
#  (471, 5, 550, datetime.datetime(2020, 1, 13, 9, 34)),
#  (472, 4, 310, datetime.datetime(2020, 1, 13, 9, 44)),
#  (473, 1, 80, datetime.datetime(2020, 1, 13, 9, 25)),
#  (474, 3, 463, datetime.datetime(2020, 1, 13, 9, 14)),
#  (475, 2, 484, datetime.datetime(2020, 1, 13, 9, 43)),
#  (476, 1, 700, datetime.datetime(2020, 1, 13, 9, 26)),
#  (477, 1, 437, datetime.datetime(2020, 1, 13, 9, 27)),
#  (478, 5, 73, datetime.datetime(2020, 1, 13, 9, 35)),
#  (479, 4, 627, datetime.datetime(2020, 1, 13, 9, 45)),
#  (480, 3, 216, datetime.datetime(2020, 1, 13, 9, 15)),
#  (481, 1, 617, datetime.datetime(2020, 1, 13, 9, 28)),
#  (482, 5, 707, datetime.datetime(2020, 1, 13, 9, 36)),
#  (483, 3, 11, datetime.datetime(2020, 1, 13, 9, 16)),
#  (484, 3, 969, datetime.datetime(2020, 1, 13, 9, 17)),
#  (485, 4, 22, datetime.datetime(2020, 1, 13, 9, 46)),
#  (486, 2, 540, datetime.datetime(2020, 1, 13, 9, 44)),
#  (487, 3, 39, datetime.datetime(2020, 1, 13, 9, 18)),
#  (488, 3, 761, datetime.datetime(2020, 1, 13, 9, 19)),
#  (489, 4, 1, datetime.datetime(2020, 1, 13, 9, 47)),
#  (490, 4, 137, datetime.datetime(2020, 1, 13, 9, 48)),
#  (491, 4, 52, datetime.datetime(2020, 1, 13, 9, 49)),
#  (492, 3, 158, datetime.datetime(2020, 1, 13, 9, 20)),
#  (493, 2, 769, datetime.datetime(2020, 1, 13, 9, 45)),
#  (494, 3, 789, datetime.datetime(2020, 1, 13, 9, 21)),
#  (495, 4, 255, datetime.datetime(2020, 1, 13, 9, 50)),
#  (496, 3, 888, datetime.datetime(2020, 1, 13, 9, 22)),
#  (497, 5, 492, datetime.datetime(2020, 1, 13, 9, 37)),
#  (498, 2, 24, datetime.datetime(2020, 1, 13, 9, 46)),
#  (499, 1, 322, datetime.datetime(2020, 1, 13, 9, 29)),
#  (500, 2, 58, datetime.datetime(2020, 1, 13, 9, 47)),
#  (501, 2, 226, datetime.datetime(2020, 1, 13, 9, 48)),
#  (502, 3, 365, datetime.datetime(2020, 1, 13, 9, 23)),
#  (503, 5, 851, datetime.datetime(2020, 1, 13, 9, 38)),
#  (504, 4, 862, datetime.datetime(2020, 1, 13, 9, 51)),
#  (505, 5, 647, datetime.datetime(2020, 1, 13, 9, 39)),
#  (506, 3, 12, datetime.datetime(2020, 1, 13, 9, 24)),
#  (507, 1, 756, datetime.datetime(2020, 1, 13, 9, 30)),
#  (508, 2, 774, datetime.datetime(2020, 1, 13, 9, 49)),
#  (509, 3, 994, datetime.datetime(2020, 1, 13, 9, 25)),
#  (510, 1, 564, datetime.datetime(2020, 1, 13, 9, 31)),
#  (511, 2, 142, datetime.datetime(2020, 1, 13, 9, 50)),
#  (512, 1, 427, datetime.datetime(2020, 1, 13, 9, 32)),
#  (513, 4, 454, datetime.datetime(2020, 1, 13, 9, 52)),
#  (514, 3, 323, datetime.datetime(2020, 1, 13, 9, 26)),
#  (515, 5, 262, datetime.datetime(2020, 1, 13, 9, 40)),
#  (516, 1, 710, datetime.datetime(2020, 1, 13, 9, 33)),
#  (517, 4, 291, datetime.datetime(2020, 1, 13, 9, 53)),
#  (518, 2, 886, datetime.datetime(2020, 1, 13, 9, 51)),
#  (519, 4, 126, datetime.datetime(2020, 1, 13, 9, 54)),
#  (520, 4, 916, datetime.datetime(2020, 1, 13, 9, 55)),
#  (521, 2, 108, datetime.datetime(2020, 1, 13, 9, 52)),
#  (522, 1, 212, datetime.datetime(2020, 1, 13, 9, 34)),
#  (523, 1, 342, datetime.datetime(2020, 1, 13, 9, 35)),
#  (524, 2, 173, datetime.datetime(2020, 1, 13, 9, 53)),
#  (525, 1, 994, datetime.datetime(2020, 1, 13, 9, 36)),
#  (526, 3, 409, datetime.datetime(2020, 1, 13, 9, 27)),
#  (527, 2, 195, datetime.datetime(2020, 1, 13, 9, 54)),
#  (528, 5, 528, datetime.datetime(2020, 1, 13, 9, 41)),
#  (529, 3, 127, datetime.datetime(2020, 1, 13, 9, 28)),
#  (530, 1, 698, datetime.datetime(2020, 1, 13, 9, 37)),
#  (531, 3, 988, datetime.datetime(2020, 1, 13, 9, 29)),
#  (532, 4, 479, datetime.datetime(2020, 1, 13, 9, 56)),
#  (533, 4, 397, datetime.datetime(2020, 1, 13, 9, 57)),
#  (534, 4, 78, datetime.datetime(2020, 1, 13, 9, 58)),
#  (535, 3, 582, datetime.datetime(2020, 1, 13, 9, 30)),
#  (536, 4, 521, datetime.datetime(2020, 1, 13, 9, 59)),
#  (537, 2, 268, datetime.datetime(2020, 1, 13, 9, 55)),
#  (538, 3, 801, datetime.datetime(2020, 1, 13, 9, 31)),
#  (539, 4, 492, datetime.datetime(2020, 1, 13, 10, 0)),
#  (540, 5, 70, datetime.datetime(2020, 1, 13, 9, 42)),
#  (541, 5, 149, datetime.datetime(2020, 1, 13, 9, 43)),
#  (542, 1, 362, datetime.datetime(2020, 1, 13, 9, 38)),
#  (543, 5, 14, datetime.datetime(2020, 1, 13, 9, 44)),
#  (544, 3, 365, datetime.datetime(2020, 1, 13, 9, 32)),
#  (545, 4, 594, datetime.datetime(2020, 1, 13, 10, 1)),
#  (546, 4, 764, datetime.datetime(2020, 1, 13, 10, 2)),
#  (547, 5, 397, datetime.datetime(2020, 1, 13, 9, 45)),
#  (548, 2, 111, datetime.datetime(2020, 1, 13, 9, 56)),
#  (549, 2, 978, datetime.datetime(2020, 1, 13, 9, 57)),
#  (550, 4, 833, datetime.datetime(2020, 1, 13, 10, 3)),
#  (551, 5, 107, datetime.datetime(2020, 1, 13, 9, 46)),
#  (552, 5, 736, datetime.datetime(2020, 1, 13, 9, 47)),
#  (553, 2, 128, datetime.datetime(2020, 1, 13, 9, 58)),
#  (554, 4, 420, datetime.datetime(2020, 1, 13, 10, 4)),
#  (555, 4, 689, datetime.datetime(2020, 1, 13, 10, 5)),
#  (556, 5, 888, datetime.datetime(2020, 1, 13, 9, 48)),
#  (557, 2, 413, datetime.datetime(2020, 1, 13, 9, 59)),
#  (558, 5, 74, datetime.datetime(2020, 1, 13, 9, 49)),
#  (559, 3, 460, datetime.datetime(2020, 1, 13, 9, 33)),
#  (560, 4, 8, datetime.datetime(2020, 1, 13, 10, 6)),
#  (561, 3, 846, datetime.datetime(2020, 1, 13, 9, 34)),
#  (562, 2, 844, datetime.datetime(2020, 1, 13, 10, 0)),
#  (563, 3, 510, datetime.datetime(2020, 1, 13, 9, 35)),
#  (564, 3, 989, datetime.datetime(2020, 1, 13, 9, 36)),
#  (565, 2, 384, datetime.datetime(2020, 1, 13, 10, 1)),
#  (566, 3, 741, datetime.datetime(2020, 1, 13, 9, 37)),
#  (567, 3, 890, datetime.datetime(2020, 1, 13, 9, 38)),
#  (568, 3, 843, datetime.datetime(2020, 1, 13, 9, 39)),
#  (569, 2, 45, datetime.datetime(2020, 1, 13, 10, 2)),
#  (570, 3, 960, datetime.datetime(2020, 1, 13, 9, 40)),
#  (571, 1, 778, datetime.datetime(2020, 1, 13, 9, 39)),
#  (572, 2, 991, datetime.datetime(2020, 1, 13, 10, 3)),
#  (573, 2, 774, datetime.datetime(2020, 1, 13, 10, 4)),
#  (574, 3, 930, datetime.datetime(2020, 1, 13, 9, 41)),
#  (575, 3, 884, datetime.datetime(2020, 1, 13, 9, 42)),
#  (576, 5, 375, datetime.datetime(2020, 1, 13, 9, 50)),
#  (577, 1, 490, datetime.datetime(2020, 1, 13, 9, 40)),
#  (578, 1, 182, datetime.datetime(2020, 1, 13, 9, 41)),
#  (579, 5, 390, datetime.datetime(2020, 1, 13, 9, 51)),
#  (580, 4, 434, datetime.datetime(2020, 1, 13, 10, 7)),
#  (581, 3, 426, datetime.datetime(2020, 1, 13, 9, 43)),
#  (582, 1, 21, datetime.datetime(2020, 1, 13, 9, 42)),
#  (583, 3, 990, datetime.datetime(2020, 1, 13, 9, 44)),
#  (584, 2, 245, datetime.datetime(2020, 1, 13, 10, 5)),
#  (585, 1, 868, datetime.datetime(2020, 1, 13, 9, 43)),
#  (586, 1, 17, datetime.datetime(2020, 1, 13, 9, 44)),
#  (587, 1, 425, datetime.datetime(2020, 1, 13, 9, 45)),
#  (588, 2, 177, datetime.datetime(2020, 1, 13, 10, 6)),
#  (589, 2, 465, datetime.datetime(2020, 1, 13, 10, 7)),
#  (590, 2, 989, datetime.datetime(2020, 1, 13, 10, 8)),
#  (591, 3, 110, datetime.datetime(2020, 1, 13, 9, 45)),
#  (592, 5, 811, datetime.datetime(2020, 1, 13, 9, 52)),
#  (593, 4, 538, datetime.datetime(2020, 1, 13, 10, 8)),
#  (594, 1, 123, datetime.datetime(2020, 1, 13, 9, 46)),
#  (595, 4, 597, datetime.datetime(2020, 1, 13, 10, 9)),
#  (596, 5, 920, datetime.datetime(2020, 1, 13, 9, 53)),
#  (597, 4, 852, datetime.datetime(2020, 1, 13, 10, 10)),
#  (598, 1, 458, datetime.datetime(2020, 1, 13, 9, 47)),
#  (599, 3, 65, datetime.datetime(2020, 1, 13, 9, 46)),
#  (600, 5, 319, datetime.datetime(2020, 1, 13, 9, 54)),
#  (601, 3, 210, datetime.datetime(2020, 1, 13, 9, 47)),
#  (602, 1, 492, datetime.datetime(2020, 1, 13, 9, 48)),
#  (603, 5, 75, datetime.datetime(2020, 1, 13, 9, 55)),
#  (604, 4, 38, datetime.datetime(2020, 1, 13, 10, 11)),
#  (605, 3, 750, datetime.datetime(2020, 1, 13, 9, 48)),
#  (606, 4, 174, datetime.datetime(2020, 1, 13, 10, 12)),
#  (607, 3, 509, datetime.datetime(2020, 1, 13, 9, 49)),
#  (608, 2, 617, datetime.datetime(2020, 1, 13, 10, 9)),
#  (609, 3, 894, datetime.datetime(2020, 1, 13, 9, 50)),
#  (610, 4, 541, datetime.datetime(2020, 1, 13, 10, 13)),
#  (611, 4, 750, datetime.datetime(2020, 1, 13, 10, 14)),
#  (612, 3, 877, datetime.datetime(2020, 1, 13, 9, 51)),
#  (613, 3, 385, datetime.datetime(2020, 1, 13, 9, 52)),
#  (614, 2, 331, datetime.datetime(2020, 1, 13, 10, 10)),
#  (615, 5, 34, datetime.datetime(2020, 1, 13, 9, 56)),
#  (616, 1, 502, datetime.datetime(2020, 1, 13, 9, 49)),
#  (617, 2, 844, datetime.datetime(2020, 1, 13, 10, 11)),
#  (618, 4, 838, datetime.datetime(2020, 1, 13, 10, 15)),
#  (619, 5, 877, datetime.datetime(2020, 1, 13, 9, 57)),
#  (620, 3, 354, datetime.datetime(2020, 1, 13, 9, 53)),
#  (621, 4, 630, datetime.datetime(2020, 1, 13, 10, 16)),
#  (622, 2, 397, datetime.datetime(2020, 1, 13, 10, 12)),
#  (623, 5, 666, datetime.datetime(2020, 1, 13, 9, 58)),
#  (624, 1, 780, datetime.datetime(2020, 1, 13, 9, 50)),
#  (625, 4, 417, datetime.datetime(2020, 1, 13, 10, 17)),
#  (626, 5, 911, datetime.datetime(2020, 1, 13, 9, 59)),
#  (627, 5, 984, datetime.datetime(2020, 1, 13, 10, 0)),
#  (628, 1, 771, datetime.datetime(2020, 1, 13, 9, 51)),
#  (629, 3, 286, datetime.datetime(2020, 1, 13, 9, 54)),
#  (630, 3, 79, datetime.datetime(2020, 1, 13, 9, 55)),
#  (631, 5, 435, datetime.datetime(2020, 1, 13, 10, 1)),
#  (632, 1, 565, datetime.datetime(2020, 1, 13, 9, 52)),
#  (633, 1, 313, datetime.datetime(2020, 1, 13, 9, 53)),
#  (634, 2, 685, datetime.datetime(2020, 1, 13, 10, 13)),
#  (635, 2, 76, datetime.datetime(2020, 1, 13, 10, 14)),
#  (636, 5, 451, datetime.datetime(2020, 1, 13, 10, 2)),
#  (637, 1, 132, datetime.datetime(2020, 1, 13, 9, 54)),
#  (638, 4, 500, datetime.datetime(2020, 1, 13, 10, 18)),
#  (639, 2, 4, datetime.datetime(2020, 1, 13, 10, 15)),
#  (640, 1, 111, datetime.datetime(2020, 1, 13, 9, 55)),
#  (641, 2, 937, datetime.datetime(2020, 1, 13, 10, 16)),
#  (642, 1, 519, datetime.datetime(2020, 1, 13, 9, 56)),
#  (643, 2, 303, datetime.datetime(2020, 1, 13, 10, 17)),
#  (644, 3, 39, datetime.datetime(2020, 1, 13, 9, 56)),
#  (645, 5, 699, datetime.datetime(2020, 1, 13, 10, 3)),
#  (646, 4, 981, datetime.datetime(2020, 1, 13, 10, 19)),
#  (647, 4, 102, datetime.datetime(2020, 1, 13, 10, 20)),
#  (648, 3, 399, datetime.datetime(2020, 1, 13, 9, 57)),
#  (649, 2, 900, datetime.datetime(2020, 1, 13, 10, 18)),
#  (650, 1, 935, datetime.datetime(2020, 1, 13, 9, 57)),
#  (651, 1, 498, datetime.datetime(2020, 1, 13, 9, 58)),
#  (652, 3, 802, datetime.datetime(2020, 1, 13, 9, 58)),
#  (653, 4, 535, datetime.datetime(2020, 1, 13, 10, 21)),
#  (654, 2, 147, datetime.datetime(2020, 1, 13, 10, 19)),
#  (655, 2, 107, datetime.datetime(2020, 1, 13, 10, 20)),
#  (656, 1, 688, datetime.datetime(2020, 1, 13, 9, 59)),
#  (657, 3, 559, datetime.datetime(2020, 1, 13, 9, 59)),
#  (658, 5, 28, datetime.datetime(2020, 1, 13, 10, 4)),
#  (659, 1, 277, datetime.datetime(2020, 1, 13, 10, 0)),
#  (660, 2, 285, datetime.datetime(2020, 1, 13, 10, 21)),
#  (661, 3, 650, datetime.datetime(2020, 1, 13, 10, 0)),
#  (662, 5, 393, datetime.datetime(2020, 1, 13, 10, 5)),
#  (663, 3, 233, datetime.datetime(2020, 1, 13, 10, 1)),
#  (664, 2, 290, datetime.datetime(2020, 1, 13, 10, 22)),
#  (665, 5, 231, datetime.datetime(2020, 1, 13, 10, 6)),
#  (666, 3, 333, datetime.datetime(2020, 1, 13, 10, 2)),
#  (667, 1, 392, datetime.datetime(2020, 1, 13, 10, 1)),
#  (668, 2, 890, datetime.datetime(2020, 1, 13, 10, 23)),
#  (669, 1, 136, datetime.datetime(2020, 1, 13, 10, 2)),
#  (670, 5, 208, datetime.datetime(2020, 1, 13, 10, 7)),
#  (671, 5, 480, datetime.datetime(2020, 1, 13, 10, 8)),
#  (672, 4, 690, datetime.datetime(2020, 1, 13, 10, 22)),
#  (673, 3, 47, datetime.datetime(2020, 1, 13, 10, 3)),
#  (674, 1, 59, datetime.datetime(2020, 1, 13, 10, 3)),
#  (675, 5, 695, datetime.datetime(2020, 1, 13, 10, 9)),
#  (676, 1, 696, datetime.datetime(2020, 1, 13, 10, 4)),
#  (677, 3, 932, datetime.datetime(2020, 1, 13, 10, 4)),
#  (678, 4, 101, datetime.datetime(2020, 1, 13, 10, 23)),
#  (679, 4, 661, datetime.datetime(2020, 1, 13, 10, 24)),
#  (680, 5, 964, datetime.datetime(2020, 1, 13, 10, 10)),
#  (681, 3, 257, datetime.datetime(2020, 1, 13, 10, 5)),
#  (682, 4, 954, datetime.datetime(2020, 1, 13, 10, 25)),
#  (683, 5, 27, datetime.datetime(2020, 1, 13, 10, 11)),
#  (684, 5, 131, datetime.datetime(2020, 1, 13, 10, 12)),
#  (685, 3, 917, datetime.datetime(2020, 1, 13, 10, 6)),
#  (686, 5, 298, datetime.datetime(2020, 1, 13, 10, 13)),
#  (687, 2, 297, datetime.datetime(2020, 1, 13, 10, 24)),
#  (688, 4, 260, datetime.datetime(2020, 1, 13, 10, 26)),
#  (689, 3, 429, datetime.datetime(2020, 1, 13, 10, 7)),
#  (690, 4, 546, datetime.datetime(2020, 1, 13, 10, 27)),
#  (691, 4, 174, datetime.datetime(2020, 1, 13, 10, 28)),
#  (692, 2, 65, datetime.datetime(2020, 1, 13, 10, 25)),
#  (693, 2, 793, datetime.datetime(2020, 1, 13, 10, 26)),
#  (694, 4, 247, datetime.datetime(2020, 1, 13, 10, 29)),
#  (695, 5, 869, datetime.datetime(2020, 1, 13, 10, 14)),
#  (696, 4, 154, datetime.datetime(2020, 1, 13, 10, 30)),
#  (697, 5, 150, datetime.datetime(2020, 1, 13, 10, 15)),
#  (698, 1, 334, datetime.datetime(2020, 1, 13, 10, 5)),
#  (699, 2, 660, datetime.datetime(2020, 1, 13, 10, 27)),
#  (700, 3, 820, datetime.datetime(2020, 1, 13, 10, 8)),
#  (701, 1, 712, datetime.datetime(2020, 1, 13, 10, 6)),
#  (702, 5, 914, datetime.datetime(2020, 1, 13, 10, 16)),
#  (703, 5, 728, datetime.datetime(2020, 1, 13, 10, 17)),
#  (704, 5, 461, datetime.datetime(2020, 1, 13, 10, 18)),
#  (705, 3, 526, datetime.datetime(2020, 1, 13, 10, 9)),
#  (706, 5, 373, datetime.datetime(2020, 1, 13, 10, 19)),
#  (707, 1, 214, datetime.datetime(2020, 1, 13, 10, 7)),
#  (708, 1, 596, datetime.datetime(2020, 1, 13, 10, 8)),
#  (709, 5, 762, datetime.datetime(2020, 1, 13, 10, 20)),
#  (710, 4, 516, datetime.datetime(2020, 1, 13, 10, 31)),
#  (711, 3, 400, datetime.datetime(2020, 1, 13, 10, 10)),
#  (712, 2, 258, datetime.datetime(2020, 1, 13, 10, 28)),
#  (713, 5, 866, datetime.datetime(2020, 1, 13, 10, 21)),
#  (714, 1, 54, datetime.datetime(2020, 1, 13, 10, 9)),
#  (715, 5, 424, datetime.datetime(2020, 1, 13, 10, 22)),
#  (716, 2, 333, datetime.datetime(2020, 1, 13, 10, 29)),
#  (717, 2, 114, datetime.datetime(2020, 1, 13, 10, 30)),
#  (718, 1, 118, datetime.datetime(2020, 1, 13, 10, 10)),
#  (719, 5, 742, datetime.datetime(2020, 1, 13, 10, 23)),
#  (720, 4, 708, datetime.datetime(2020, 1, 13, 10, 32)),
#  (721, 2, 690, datetime.datetime(2020, 1, 13, 10, 31)),
#  (722, 2, 880, datetime.datetime(2020, 1, 13, 10, 32)),
#  (723, 4, 162, datetime.datetime(2020, 1, 13, 10, 33)),
#  (724, 4, 592, datetime.datetime(2020, 1, 13, 10, 34)),
#  (725, 3, 727, datetime.datetime(2020, 1, 13, 10, 11)),
#  (726, 2, 707, datetime.datetime(2020, 1, 13, 10, 33)),
#  (727, 5, 525, datetime.datetime(2020, 1, 13, 10, 24)),
#  (728, 1, 47, datetime.datetime(2020, 1, 13, 10, 11)),
#  (729, 4, 225, datetime.datetime(2020, 1, 13, 10, 35)),
#  (730, 4, 732, datetime.datetime(2020, 1, 13, 10, 36)),
#  (731, 2, 773, datetime.datetime(2020, 1, 13, 10, 34)),
#  (732, 4, 286, datetime.datetime(2020, 1, 13, 10, 37)),
#  (733, 5, 302, datetime.datetime(2020, 1, 13, 10, 25)),
#  (734, 2, 686, datetime.datetime(2020, 1, 13, 10, 35)),
#  (735, 4, 62, datetime.datetime(2020, 1, 13, 10, 38)),
#  (736, 4, 992, datetime.datetime(2020, 1, 13, 10, 39)),
#  (737, 3, 524, datetime.datetime(2020, 1, 13, 10, 12)),
#  (738, 1, 681, datetime.datetime(2020, 1, 13, 10, 12)),
#  (739, 3, 680, datetime.datetime(2020, 1, 13, 10, 13)),
#  (740, 3, 664, datetime.datetime(2020, 1, 13, 10, 14)),
#  (741, 4, 463, datetime.datetime(2020, 1, 13, 10, 40)),
#  (742, 2, 325, datetime.datetime(2020, 1, 13, 10, 36)),
#  (743, 2, 340, datetime.datetime(2020, 1, 13, 10, 37)),
#  (744, 2, 667, datetime.datetime(2020, 1, 13, 10, 38)),
#  (745, 3, 772, datetime.datetime(2020, 1, 13, 10, 15)),
#  (746, 2, 322, datetime.datetime(2020, 1, 13, 10, 39)),
#  (747, 4, 181, datetime.datetime(2020, 1, 13, 10, 41)),
#  (748, 3, 546, datetime.datetime(2020, 1, 13, 10, 16)),
#  (749, 3, 479, datetime.datetime(2020, 1, 13, 10, 17)),
#  (750, 1, 895, datetime.datetime(2020, 1, 13, 10, 13)),
#  (751, 4, 402, datetime.datetime(2020, 1, 13, 10, 42)),
#  (752, 3, 951, datetime.datetime(2020, 1, 13, 10, 18)),
#  (753, 4, 580, datetime.datetime(2020, 1, 13, 10, 43)),
#  (754, 1, 609, datetime.datetime(2020, 1, 13, 10, 14)),
#  (755, 4, 46, datetime.datetime(2020, 1, 13, 10, 44)),
#  (756, 1, 998, datetime.datetime(2020, 1, 13, 10, 15)),
#  (757, 1, 537, datetime.datetime(2020, 1, 13, 10, 16)),
#  (758, 5, 716, datetime.datetime(2020, 1, 13, 10, 26)),
#  (759, 4, 896, datetime.datetime(2020, 1, 13, 10, 45)),
#  (760, 1, 240, datetime.datetime(2020, 1, 13, 10, 17)),
#  (761, 1, 93, datetime.datetime(2020, 1, 13, 10, 18)),
#  (762, 4, 89, datetime.datetime(2020, 1, 13, 10, 46)),
#  (763, 4, 438, datetime.datetime(2020, 1, 13, 10, 47)),
#  (764, 5, 284, datetime.datetime(2020, 1, 13, 10, 27)),
#  (765, 1, 31, datetime.datetime(2020, 1, 13, 10, 19)),
#  (766, 5, 222, datetime.datetime(2020, 1, 13, 10, 28)),
#  (767, 3, 512, datetime.datetime(2020, 1, 13, 10, 19)),
#  (768, 1, 560, datetime.datetime(2020, 1, 13, 10, 20)),
#  (769, 3, 715, datetime.datetime(2020, 1, 13, 10, 20)),
#  (770, 3, 976, datetime.datetime(2020, 1, 13, 10, 21)),
#  (771, 1, 830, datetime.datetime(2020, 1, 13, 10, 21)),
#  (772, 5, 278, datetime.datetime(2020, 1, 13, 10, 29)),
#  (773, 2, 604, datetime.datetime(2020, 1, 13, 10, 40)),
#  (774, 2, 856, datetime.datetime(2020, 1, 13, 10, 41)),
#  (775, 5, 573, datetime.datetime(2020, 1, 13, 10, 30)),
#  (776, 4, 220, datetime.datetime(2020, 1, 13, 10, 48)),
#  (777, 2, 181, datetime.datetime(2020, 1, 13, 10, 42)),
#  (778, 5, 748, datetime.datetime(2020, 1, 13, 10, 31)),
#  (779, 2, 260, datetime.datetime(2020, 1, 13, 10, 43)),
#  (780, 5, 598, datetime.datetime(2020, 1, 13, 10, 32)),
#  (781, 5, 530, datetime.datetime(2020, 1, 13, 10, 33)),
#  (782, 4, 205, datetime.datetime(2020, 1, 13, 10, 49)),
#  (783, 3, 268, datetime.datetime(2020, 1, 13, 10, 22)),
#  (784, 4, 633, datetime.datetime(2020, 1, 13, 10, 50)),
#  (785, 1, 368, datetime.datetime(2020, 1, 13, 10, 22)),
#  (786, 1, 371, datetime.datetime(2020, 1, 13, 10, 23)),
#  (787, 1, 248, datetime.datetime(2020, 1, 13, 10, 24)),
#  (788, 3, 256, datetime.datetime(2020, 1, 13, 10, 23)),
#  (789, 1, 691, datetime.datetime(2020, 1, 13, 10, 25)),
#  (790, 5, 118, datetime.datetime(2020, 1, 13, 10, 34)),
#  (791, 3, 906, datetime.datetime(2020, 1, 13, 10, 24)),
#  (792, 2, 30, datetime.datetime(2020, 1, 13, 10, 44)),
#  (793, 5, 825, datetime.datetime(2020, 1, 13, 10, 35)),
#  (794, 5, 664, datetime.datetime(2020, 1, 13, 10, 36)),
#  (795, 1, 292, datetime.datetime(2020, 1, 13, 10, 26)),
#  (796, 1, 120, datetime.datetime(2020, 1, 13, 10, 27)),
#  (797, 2, 178, datetime.datetime(2020, 1, 13, 10, 45)),
#  (798, 1, 839, datetime.datetime(2020, 1, 13, 10, 28)),
#  (799, 4, 148, datetime.datetime(2020, 1, 13, 10, 51)),
#  (800, 3, 693, datetime.datetime(2020, 1, 13, 10, 25)),
#  (801, 1, 969, datetime.datetime(2020, 1, 13, 10, 29)),
#  (802, 5, 719, datetime.datetime(2020, 1, 13, 10, 37)),
#  (803, 1, 738, datetime.datetime(2020, 1, 13, 10, 30)),
#  (804, 4, 347, datetime.datetime(2020, 1, 13, 10, 52)),
#  (805, 5, 222, datetime.datetime(2020, 1, 13, 10, 38)),
#  (806, 5, 349, datetime.datetime(2020, 1, 13, 10, 39)),
#  (807, 4, 166, datetime.datetime(2020, 1, 13, 10, 53)),
#  (808, 5, 50, datetime.datetime(2020, 1, 13, 10, 40)),
#  (809, 3, 361, datetime.datetime(2020, 1, 13, 10, 26)),
#  (810, 2, 509, datetime.datetime(2020, 1, 13, 10, 46)),
#  (811, 1, 971, datetime.datetime(2020, 1, 13, 10, 31)),
#  (812, 5, 50, datetime.datetime(2020, 1, 13, 10, 41)),
#  (813, 2, 907, datetime.datetime(2020, 1, 13, 10, 47)),
#  (814, 4, 111, datetime.datetime(2020, 1, 13, 10, 54)),
#  (815, 1, 78, datetime.datetime(2020, 1, 13, 10, 32)),
#  (816, 3, 215, datetime.datetime(2020, 1, 13, 10, 27)),
#  (817, 3, 694, datetime.datetime(2020, 1, 13, 10, 28)),
#  (818, 4, 485, datetime.datetime(2020, 1, 13, 10, 55)),
#  (819, 3, 153, datetime.datetime(2020, 1, 13, 10, 29)),
#  (820, 3, 663, datetime.datetime(2020, 1, 13, 10, 30)),
#  (821, 5, 821, datetime.datetime(2020, 1, 13, 10, 42)),
#  (822, 2, 783, datetime.datetime(2020, 1, 13, 10, 48)),
#  (823, 3, 549, datetime.datetime(2020, 1, 13, 10, 31)),
#  (824, 1, 462, datetime.datetime(2020, 1, 13, 10, 33)),
#  (825, 1, 951, datetime.datetime(2020, 1, 13, 10, 34)),
#  (826, 4, 655, datetime.datetime(2020, 1, 13, 10, 56)),
#  (827, 1, 370, datetime.datetime(2020, 1, 13, 10, 35)),
#  (828, 5, 54, datetime.datetime(2020, 1, 13, 10, 43)),
#  (829, 4, 986, datetime.datetime(2020, 1, 13, 10, 57)),
#  (830, 5, 497, datetime.datetime(2020, 1, 13, 10, 44)),
#  (831, 3, 766, datetime.datetime(2020, 1, 13, 10, 32)),
#  (832, 5, 677, datetime.datetime(2020, 1, 13, 10, 45)),
#  (833, 1, 251, datetime.datetime(2020, 1, 13, 10, 36)),
#  (834, 3, 53, datetime.datetime(2020, 1, 13, 10, 33)),
#  (835, 4, 746, datetime.datetime(2020, 1, 13, 10, 58)),
#  (836, 4, 475, datetime.datetime(2020, 1, 13, 10, 59)),
#  (837, 3, 238, datetime.datetime(2020, 1, 13, 10, 34)),
#  (838, 3, 524, datetime.datetime(2020, 1, 13, 10, 35)),
#  (839, 1, 291, datetime.datetime(2020, 1, 13, 10, 37)),
#  (840, 4, 154, datetime.datetime(2020, 1, 13, 11, 0)),
#  (841, 3, 638, datetime.datetime(2020, 1, 13, 10, 36)),
#  (842, 3, 604, datetime.datetime(2020, 1, 13, 10, 37)),
#  (843, 2, 995, datetime.datetime(2020, 1, 13, 10, 49)),
#  (844, 1, 369, datetime.datetime(2020, 1, 13, 10, 38)),
#  (845, 5, 956, datetime.datetime(2020, 1, 13, 10, 46)),
#  (846, 2, 129, datetime.datetime(2020, 1, 13, 10, 50)),
#  (847, 2, 719, datetime.datetime(2020, 1, 13, 10, 51)),
#  (848, 5, 118, datetime.datetime(2020, 1, 13, 10, 47)),
#  (849, 1, 287, datetime.datetime(2020, 1, 13, 10, 39)),
#  (850, 5, 944, datetime.datetime(2020, 1, 13, 10, 48)),
#  (851, 5, 805, datetime.datetime(2020, 1, 13, 10, 49)),
#  (852, 2, 981, datetime.datetime(2020, 1, 13, 10, 52)),
#  (853, 1, 557, datetime.datetime(2020, 1, 13, 10, 40)),
#  (854, 4, 864, datetime.datetime(2020, 1, 13, 11, 1)),
#  (855, 3, 605, datetime.datetime(2020, 1, 13, 10, 38)),
#  (856, 3, 149, datetime.datetime(2020, 1, 13, 10, 39)),
#  (857, 4, 390, datetime.datetime(2020, 1, 13, 11, 2)),
#  (858, 5, 731, datetime.datetime(2020, 1, 13, 10, 50)),
#  (859, 4, 311, datetime.datetime(2020, 1, 13, 11, 3)),
#  (860, 2, 116, datetime.datetime(2020, 1, 13, 10, 53)),
#  (861, 3, 78, datetime.datetime(2020, 1, 13, 10, 40)),
#  (862, 3, 14, datetime.datetime(2020, 1, 13, 10, 41)),
#  (863, 2, 570, datetime.datetime(2020, 1, 13, 10, 54)),
#  (864, 4, 618, datetime.datetime(2020, 1, 13, 11, 4)),
#  (865, 5, 127, datetime.datetime(2020, 1, 13, 10, 51)),
#  (866, 4, 212, datetime.datetime(2020, 1, 13, 11, 5)),
#  (867, 5, 222, datetime.datetime(2020, 1, 13, 10, 52)),
#  (868, 4, 151, datetime.datetime(2020, 1, 13, 11, 6)),
#  (869, 3, 255, datetime.datetime(2020, 1, 13, 10, 42)),
#  (870, 2, 831, datetime.datetime(2020, 1, 13, 10, 55)),
#  (871, 1, 490, datetime.datetime(2020, 1, 13, 10, 41)),
#  (872, 1, 394, datetime.datetime(2020, 1, 13, 10, 42)),
#  (873, 3, 992, datetime.datetime(2020, 1, 13, 10, 43)),
#  (874, 4, 283, datetime.datetime(2020, 1, 13, 11, 7)),
#  (875, 2, 545, datetime.datetime(2020, 1, 13, 10, 56)),
#  (876, 2, 49, datetime.datetime(2020, 1, 13, 10, 57)),
#  (877, 3, 522, datetime.datetime(2020, 1, 13, 10, 44)),
#  (878, 2, 46, datetime.datetime(2020, 1, 13, 10, 58)),
#  (879, 2, 160, datetime.datetime(2020, 1, 13, 10, 59)),
#  (880, 4, 579, datetime.datetime(2020, 1, 13, 11, 8)),
#  (881, 3, 851, datetime.datetime(2020, 1, 13, 10, 45)),
#  (882, 4, 976, datetime.datetime(2020, 1, 13, 11, 9)),
#  (883, 4, 536, datetime.datetime(2020, 1, 13, 11, 10)),
#  (884, 5, 233, datetime.datetime(2020, 1, 13, 10, 53)),
#  (885, 4, 259, datetime.datetime(2020, 1, 13, 11, 11)),
#  (886, 5, 837, datetime.datetime(2020, 1, 13, 10, 54)),
#  (887, 2, 148, datetime.datetime(2020, 1, 13, 11, 0)),
#  (888, 3, 290, datetime.datetime(2020, 1, 13, 10, 46)),
#  (889, 5, 549, datetime.datetime(2020, 1, 13, 10, 55)),
#  (890, 1, 941, datetime.datetime(2020, 1, 13, 10, 43)),
#  (891, 1, 179, datetime.datetime(2020, 1, 13, 10, 44)),
#  (892, 5, 147, datetime.datetime(2020, 1, 13, 10, 56)),
#  (893, 5, 274, datetime.datetime(2020, 1, 13, 10, 57)),
#  (894, 3, 621, datetime.datetime(2020, 1, 13, 10, 47)),
#  (895, 3, 989, datetime.datetime(2020, 1, 13, 10, 48)),
#  (896, 3, 782, datetime.datetime(2020, 1, 13, 10, 49)),
#  (897, 5, 842, datetime.datetime(2020, 1, 13, 10, 58)),
#  (898, 4, 527, datetime.datetime(2020, 1, 13, 11, 12)),
#  (899, 4, 160, datetime.datetime(2020, 1, 13, 11, 13)),
#  (900, 1, 636, datetime.datetime(2020, 1, 13, 10, 45)),
#  (901, 3, 93, datetime.datetime(2020, 1, 13, 10, 50)),
#  (902, 4, 572, datetime.datetime(2020, 1, 13, 11, 14)),
#  (903, 3, 422, datetime.datetime(2020, 1, 13, 10, 51)),
#  (904, 2, 296, datetime.datetime(2020, 1, 13, 11, 1)),
#  (905, 5, 771, datetime.datetime(2020, 1, 13, 10, 59)),
#  (906, 3, 385, datetime.datetime(2020, 1, 13, 10, 52)),
#  (907, 3, 523, datetime.datetime(2020, 1, 13, 10, 53)),
#  (908, 5, 390, datetime.datetime(2020, 1, 13, 11, 0)),
#  (909, 1, 472, datetime.datetime(2020, 1, 13, 10, 46)),
#  (910, 3, 667, datetime.datetime(2020, 1, 13, 10, 54)),
#  (911, 5, 936, datetime.datetime(2020, 1, 13, 11, 1)),
#  (912, 4, 700, datetime.datetime(2020, 1, 13, 11, 15)),
#  (913, 5, 869, datetime.datetime(2020, 1, 13, 11, 2)),
#  (914, 4, 247, datetime.datetime(2020, 1, 13, 11, 16)),
#  (915, 1, 614, datetime.datetime(2020, 1, 13, 10, 47)),
#  (916, 5, 15, datetime.datetime(2020, 1, 13, 11, 3)),
#  (917, 2, 624, datetime.datetime(2020, 1, 13, 11, 2)),
#  (918, 1, 281, datetime.datetime(2020, 1, 13, 10, 48)),
#  (919, 2, 761, datetime.datetime(2020, 1, 13, 11, 3)),
#  (920, 2, 141, datetime.datetime(2020, 1, 13, 11, 4)),
#  (921, 2, 697, datetime.datetime(2020, 1, 13, 11, 5)),
#  (922, 1, 54, datetime.datetime(2020, 1, 13, 10, 49)),
#  (923, 2, 50, datetime.datetime(2020, 1, 13, 11, 6)),
#  (924, 4, 970, datetime.datetime(2020, 1, 13, 11, 17)),
#  (925, 5, 463, datetime.datetime(2020, 1, 13, 11, 4)),
#  (926, 3, 369, datetime.datetime(2020, 1, 13, 10, 55)),
#  (927, 4, 888, datetime.datetime(2020, 1, 13, 11, 18)),
#  (928, 1, 979, datetime.datetime(2020, 1, 13, 10, 50)),
#  (929, 2, 406, datetime.datetime(2020, 1, 13, 11, 7)),
#  (930, 4, 847, datetime.datetime(2020, 1, 13, 11, 19)),
#  (931, 5, 173, datetime.datetime(2020, 1, 13, 11, 5)),
#  (932, 4, 359, datetime.datetime(2020, 1, 13, 11, 20)),
#  (933, 1, 707, datetime.datetime(2020, 1, 13, 10, 51)),
#  (934, 2, 86, datetime.datetime(2020, 1, 13, 11, 8)),
#  (935, 3, 699, datetime.datetime(2020, 1, 13, 10, 56)),
#  (936, 4, 440, datetime.datetime(2020, 1, 13, 11, 21)),
#  (937, 5, 406, datetime.datetime(2020, 1, 13, 11, 6)),
#  (938, 5, 604, datetime.datetime(2020, 1, 13, 11, 7)),
#  (939, 2, 231, datetime.datetime(2020, 1, 13, 11, 9)),
#  (940, 2, 441, datetime.datetime(2020, 1, 13, 11, 10)),
#  (941, 3, 890, datetime.datetime(2020, 1, 13, 10, 57)),
#  (942, 1, 116, datetime.datetime(2020, 1, 13, 10, 52)),
#  (943, 3, 752, datetime.datetime(2020, 1, 13, 10, 58)),
#  (944, 1, 226, datetime.datetime(2020, 1, 13, 10, 53)),
#  (945, 5, 602, datetime.datetime(2020, 1, 13, 11, 8)),
#  (946, 5, 33, datetime.datetime(2020, 1, 13, 11, 9)),
#  (947, 1, 217, datetime.datetime(2020, 1, 13, 10, 54)),
#  (948, 5, 261, datetime.datetime(2020, 1, 13, 11, 10)),
#  (949, 1, 613, datetime.datetime(2020, 1, 13, 10, 55)),
#  (950, 2, 597, datetime.datetime(2020, 1, 13, 11, 11)),
#  (951, 4, 555, datetime.datetime(2020, 1, 13, 11, 22)),
#  (952, 2, 939, datetime.datetime(2020, 1, 13, 11, 12)),
#  (953, 5, 868, datetime.datetime(2020, 1, 13, 11, 11)),
#  (954, 4, 894, datetime.datetime(2020, 1, 13, 11, 23)),
#  (955, 4, 378, datetime.datetime(2020, 1, 13, 11, 24)),
#  (956, 3, 460, datetime.datetime(2020, 1, 13, 10, 59)),
#  (957, 1, 711, datetime.datetime(2020, 1, 13, 10, 56)),
#  (958, 5, 451, datetime.datetime(2020, 1, 13, 11, 12)),
#  (959, 1, 818, datetime.datetime(2020, 1, 13, 10, 57)),
#  (960, 5, 692, datetime.datetime(2020, 1, 13, 11, 13)),
#  (961, 1, 74, datetime.datetime(2020, 1, 13, 10, 58)),
#  (962, 1, 885, datetime.datetime(2020, 1, 13, 10, 59)),
#  (963, 3, 596, datetime.datetime(2020, 1, 13, 11, 0)),
#  (964, 5, 809, datetime.datetime(2020, 1, 13, 11, 14)),
#  (965, 4, 874, datetime.datetime(2020, 1, 13, 11, 25)),
#  (966, 1, 54, datetime.datetime(2020, 1, 13, 11, 0)),
#  (967, 3, 407, datetime.datetime(2020, 1, 13, 11, 1)),
#  (968, 4, 604, datetime.datetime(2020, 1, 13, 11, 26)),
#  (969, 1, 961, datetime.datetime(2020, 1, 13, 11, 1)),
#  (970, 3, 468, datetime.datetime(2020, 1, 13, 11, 2)),
#  (971, 3, 528, datetime.datetime(2020, 1, 13, 11, 3)),
#  (972, 5, 461, datetime.datetime(2020, 1, 13, 11, 15)),
#  (973, 4, 915, datetime.datetime(2020, 1, 13, 11, 27)),
#  (974, 5, 383, datetime.datetime(2020, 1, 13, 11, 16)),
#  (975, 5, 56, datetime.datetime(2020, 1, 13, 11, 17)),
#  (976, 3, 246, datetime.datetime(2020, 1, 13, 11, 4)),
#  (977, 5, 332, datetime.datetime(2020, 1, 13, 11, 18)),
#  (978, 3, 842, datetime.datetime(2020, 1, 13, 11, 5)),
#  (979, 5, 184, datetime.datetime(2020, 1, 13, 11, 19)),
#  (980, 4, 426, datetime.datetime(2020, 1, 13, 11, 28)),
#  (981, 1, 602, datetime.datetime(2020, 1, 13, 11, 2)),
#  (982, 3, 622, datetime.datetime(2020, 1, 13, 11, 6)),
#  (983, 2, 228, datetime.datetime(2020, 1, 13, 11, 13)),
#  (984, 2, 354, datetime.datetime(2020, 1, 13, 11, 14)),
#  (985, 4, 24, datetime.datetime(2020, 1, 13, 11, 29)),
#  (986, 4, 158, datetime.datetime(2020, 1, 13, 11, 30)),
#  (987, 3, 713, datetime.datetime(2020, 1, 13, 11, 7)),
#  (988, 3, 414, datetime.datetime(2020, 1, 13, 11, 8)),
#  (989, 5, 141, datetime.datetime(2020, 1, 13, 11, 20)),
#  (990, 5, 713, datetime.datetime(2020, 1, 13, 11, 21)),
#  (991, 2, 273, datetime.datetime(2020, 1, 13, 11, 15)),
#  (992, 1, 701, datetime.datetime(2020, 1, 13, 11, 3)),
#  (993, 5, 452, datetime.datetime(2020, 1, 13, 11, 22)),
#  (994, 5, 640, datetime.datetime(2020, 1, 13, 11, 23)),
#  (995, 5, 615, datetime.datetime(2020, 1, 13, 11, 24)),
#  (996, 1, 972, datetime.datetime(2020, 1, 13, 11, 4)),
#  (997, 4, 676, datetime.datetime(2020, 1, 13, 11, 31)),
#  (998, 2, 274, datetime.datetime(2020, 1, 13, 11, 16)),
#  (999, 5, 792, datetime.datetime(2020, 1, 13, 11, 25)),
#  (1000, 4, 954, datetime.datetime(2020, 1, 13, 11, 32)),
#  ...]

# %% [markdown]
# ### Cantidad de datos dentro de la tabla "transactions"

# %%
# Consulta a la BD 
objCursor.execute("SELECT count(*) FROM transactions;")
filas = objCursor.fetchall()
filas
# Out:
# [(1010,)]

# %% [markdown]
# ### Confirmación permanente (finalización de la transacción) de ingreso de datos en tabla "transactions"

# %%
# Guardar el Cambio permanente 
obj.commit()

# %% [markdown]
# ### Cerrar la conexión entre Psycopg2 y la BD PostgreSQL

# %%
# Cierre de objeto cursor
objCursor.close()

# Cierre del objeto de las Variables de Conexión
obj.close()

# %% [markdown]
# # **** FIN DE GENERADOR DE TRANSACCIONES ****

# %%
import findspark
findspark.init('C:\spark')

from datetime import datetime
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, date_format, udf 
from pyspark.sql.types import DateType

spark = SparkSession \
    .builder \
    .appName("Basic JDBC pipeline") \
    .config("spark.driver.extraClassPath", "C:\Spark\jdbcdriver\postgresql-42.2.9.jar") \
    .config("spark.executor.extraClassPath", "C:\Spark\jdbcdriver\postgresql-42.2.9.jar") \
    .getOrCreate()

# %%
# Reading single DataFrame in Spark by retrieving all rows from a DB table.
df = spark \
    .read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://localhost/test") \
    .option("user", "postgres") \
    .option("password", "bd2019%") \
    .option("dbtable", "transactions") \
    .load()

df.show()
# Out:
# +---+-----------+------+-------------------+
# | id|customer_id|amount|       purchased_at|
# +---+-----------+------+-------------------+
# |  1|          1|    55|2017-03-01 09:00:00|
# |  2|          1|   125|2017-03-01 10:00:00|
# |  3|          1|    32|2017-03-02 13:00:00|
# |  4|          1|    64|2017-03-02 15:00:00|
# |  5|          1|   128|2017-03-03 10:00:00|
# |  6|          2|   333|2017-03-01 09:00:00|
# |  7|          2|   334|2017-03-01 09:01:00|
# |  8|          2|   333|2017-03-01 09:02:00|
# |  9|          2|    11|2017-03-03 20:00:00|
# | 10|          2|    44|2017-03-03 20:15:00|
# | 11|          3|   298|2020-01-13 08:00:00|
# | 12|          2|   668|2020-01-13 08:00:00|
# | 13|          2|   683|2020-01-13 08:01:00|
# | 14|          2|   891|2020-01-13 08:02:00|
# | 15|          2|   657|2020-01-13 08:03:00|
# | 16|          2|   134|2020-01-13 08:04:00|
# | 17|          1|   545|2020-01-13 08:00:00|
# | 18|          2|   763|2020-01-13 08:05:00|
# | 19|          3|    31|2020-01-13 08:01:00|
# | 20|          4|   130|2020-01-13 08:00:00|
# +---+-----------+------+-------------------+
# only showing top 20 rows

# %% [markdown]
# Leer datos directamente rara vez es el objetivo primario. Las dos tareas típicas son: transformar algunas de las columnas en representaciones modificadas de las mismas, o bien, agregar grupos de filas en una. A manera de ejemplo, podemos asumir que se quiere la información del total de compras hechas por clientes.
#
# Spark provee ciertas transformaciones básicas. Por ejemplo, transformar fechas a una representación con formato específico, para poder truncar la una estampilla de tiempo a nivel de día. En este caso, se utiliza `date_format` en el módulo `pyspark.sql.functions`. El siguiente código crea una columna nueva después de aplicar la transformación.

# %%
formatted_df = df.withColumn("date_string", date_format(col("purchased_at"), 'MM/dd/yyyy'))
formatted_df.show()
# Out:
# +---+-----------+------+-------------------+-----------+
# | id|customer_id|amount|       purchased_at|date_string|
# +---+-----------+------+-------------------+-----------+
# |  1|          1|    55|2017-03-01 09:00:00| 03/01/2017|
# |  2|          1|   125|2017-03-01 10:00:00| 03/01/2017|
# |  3|          1|    32|2017-03-02 13:00:00| 03/02/2017|
# |  4|          1|    64|2017-03-02 15:00:00| 03/02/2017|
# |  5|          1|   128|2017-03-03 10:00:00| 03/03/2017|
# |  6|          2|   333|2017-03-01 09:00:00| 03/01/2017|
# |  7|          2|   334|2017-03-01 09:01:00| 03/01/2017|
# |  8|          2|   333|2017-03-01 09:02:00| 03/01/2017|
# |  9|          2|    11|2017-03-03 20:00:00| 03/03/2017|
# | 10|          2|    44|2017-03-03 20:15:00| 03/03/2017|
# | 11|          3|   298|2020-01-13 08:00:00| 01/13/2020|
# | 12|          2|   668|2020-01-13 08:00:00| 01/13/2020|
# | 13|          2|   683|2020-01-13 08:01:00| 01/13/2020|
# | 14|          2|   891|2020-01-13 08:02:00| 01/13/2020|
# | 15|          2|   657|2020-01-13 08:03:00| 01/13/2020|
# | 16|          2|   134|2020-01-13 08:04:00| 01/13/2020|
# | 17|          1|   545|2020-01-13 08:00:00| 01/13/2020|
# | 18|          2|   763|2020-01-13 08:05:00| 01/13/2020|
# | 19|          3|    31|2020-01-13 08:01:00| 01/13/2020|
# | 20|          4|   130|2020-01-13 08:00:00| 01/13/2020|
# +---+-----------+------+-------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# En el caso que necesitemos crear una función que no es parte de la biblioteca estándar en Spark, es posible definir funciones creadas por el usuario (User Defined Functions o *udf*). La noción básica de una `udf` en Spark un lambda acompañado por el tipo de dato retornado. Lo anterior es estrictamente necesario en lenguajes con un sistema de tipos débil.
#
# Además, es una manera cómoda de encapsular funciones de Python que deben ser aplicadas a celdas del *Dataframe*, pero aún no tienen su implementación en las bibliotecas.
#
# El siguiente ejemplo muestra la columna creada previamente (tipo `string`) y la transforma en un tipo `DateType` propio de Spark.

# %%
string_to_date = \
    udf(lambda text_date: datetime.strptime(text_date, '%m/%d/%Y'),
        DateType())

typed_df = formatted_df.withColumn("date", string_to_date(formatted_df.date_string))
typed_df.show()
typed_df.printSchema()
# Out:
# +---+-----------+------+-------------------+-----------+----------+
# | id|customer_id|amount|       purchased_at|date_string|      date|
# +---+-----------+------+-------------------+-----------+----------+
# |  1|          1|    55|2017-03-01 09:00:00| 03/01/2017|2017-03-01|
# |  2|          1|   125|2017-03-01 10:00:00| 03/01/2017|2017-03-01|
# |  3|          1|    32|2017-03-02 13:00:00| 03/02/2017|2017-03-02|
# |  4|          1|    64|2017-03-02 15:00:00| 03/02/2017|2017-03-02|
# |  5|          1|   128|2017-03-03 10:00:00| 03/03/2017|2017-03-03|
# |  6|          2|   333|2017-03-01 09:00:00| 03/01/2017|2017-03-01|
# |  7|          2|   334|2017-03-01 09:01:00| 03/01/2017|2017-03-01|
# |  8|          2|   333|2017-03-01 09:02:00| 03/01/2017|2017-03-01|
# |  9|          2|    11|2017-03-03 20:00:00| 03/03/2017|2017-03-03|
# | 10|          2|    44|2017-03-03 20:15:00| 03/03/2017|2017-03-03|
# | 11|          3|   298|2020-01-13 08:00:00| 01/13/2020|2020-01-13|
# | 12|          2|   668|2020-01-13 08:00:00| 01/13/2020|2020-01-13|
# | 13|          2|   683|2020-01-13 08:01:00| 01/13/2020|2020-01-13|
# | 14|          2|   891|2020-01-13 08:02:00| 01/13/2020|2020-01-13|
# | 15|          2|   657|2020-01-13 08:03:00| 01/13/2020|2020-01-13|
# | 16|          2|   134|2020-01-13 08:04:00| 01/13/2020|2020-01-13|
# | 17|          1|   545|2020-01-13 08:00:00| 01/13/2020|2020-01-13|
# | 18|          2|   763|2020-01-13 08:05:00| 01/13/2020|2020-01-13|
# | 19|          3|    31|2020-01-13 08:01:00| 01/13/2020|2020-01-13|
# | 20|          4|   130|2020-01-13 08:00:00| 01/13/2020|2020-01-13|
# +---+-----------+------+-------------------+-----------+----------+
# only showing top 20 rows
#
# root
#  |-- id: integer (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- amount: integer (nullable = true)
#  |-- purchased_at: timestamp (nullable = true)
#  |-- date_string: string (nullable = true)
#  |-- date: date (nullable = true)

# %% [markdown]
# Para sumar los datos podemos utilizar el concepto común de agrupamiento en SQL. Spark posee una agrupación de `groupBy`, directamente. En este caso, queremos sumar todas las compras por cliente y día:

# %%
sum_df = typed_df.groupBy("customer_id", "date").sum()
sum_df.show()
# Out:
# +-----------+----------+-------+----------------+-----------+
# |customer_id|      date|sum(id)|sum(customer_id)|sum(amount)|
# +-----------+----------+-------+----------------+-----------+
# |          5|2020-01-13| 110676|            1040|     100754|
# |          2|2017-03-01|     21|               6|       1000|
# |          1|2017-03-02|      7|               2|         96|
# |          1|2017-03-03|      5|               1|        128|
# |          2|2020-01-13|  92175|             396|      96516|
# |          3|2020-01-13| 100015|             573|      94898|
# |          1|2020-01-13|  97818|             187|      86628|
# |          1|2017-03-01|      3|               2|        180|
# |          4|2020-01-13| 109816|             864|     107944|
# |          2|2017-03-03|     19|               4|         55|
# +-----------+----------+-------+----------------+-----------+

# %% [markdown]
# Spark sumará todas las columnas **que no se encuentren** especificadas en la operación `groupBy`. Algunos resultados no tienen interpretación últil. Por ejemplo, sumar la columna `customer_id` no da ningún valor agregado. Finalmente, es posible dar a las columnas un nombre más amigable con los consumidores de los datos.

# %%
stats_df = \
    sum_df.select(
        col('customer_id'),
        col('date'),
        col('sum(amount)').alias('amount'))

stats_df.printSchema()
stats_df.show()
# Out:
# root
#  |-- customer_id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- amount: long (nullable = true)
#
# +-----------+----------+------+
# |customer_id|      date|amount|
# +-----------+----------+------+
# |          5|2020-01-13|100754|
# |          2|2017-03-01|  1000|
# |          1|2017-03-02|    96|
# |          1|2017-03-03|   128|
# |          2|2020-01-13| 96516|
# |          3|2020-01-13| 94898|
# |          1|2020-01-13| 86628|
# |          1|2017-03-01|   180|
# |          4|2020-01-13|107944|
# |          2|2017-03-03|    55|
# +-----------+----------+------+

# %% [markdown]
# Spark permite cargar información de múltiples fuentes. A continuación se muestra como cargar datos de un archivo CSV que contiene los nombres de los clientes, así como la moneda en que realizan transacciones. Nótese que el CSV no tiene información de tipos de datos, por lo que es buena práctica agregarlos explícitamente.

# %%
from pyspark.sql.types import IntegerType, StringType, StructField, StructType

names_df = spark \
    .read \
    .format("csv") \
    .option("path", "names.csv") \
    .option("header", True) \
    .schema(StructType([
                StructField("id", IntegerType()),
                StructField("name", StringType()),
                StructField("currency", StringType())])) \
    .load()

names_df.printSchema()
names_df.show()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- currency: string (nullable = true)
#
# +---+----+--------+
# | id|name|currency|
# +---+----+--------+
# |  1|John|     CRC|
# |  2|Jane|     EUR|
# +---+----+--------+

# %% [markdown]
# Una vez que la información fue cargada, la fuente particular no es relevante. A continuación se muestra como podemos enriquerecer la información utilizando la funcion **JOIN** entre *data frames*.

# %%
joint_df = stats_df.join(names_df, stats_df.customer_id == names_df.id)
joint_df.printSchema()
joint_df.show()
# Out:
# root
#  |-- customer_id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- amount: long (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- currency: string (nullable = true)
#
# +-----------+----------+------+---+----+--------+
# |customer_id|      date|amount| id|name|currency|
# +-----------+----------+------+---+----+--------+
# |          2|2017-03-01|  1000|  2|Jane|     EUR|
# |          1|2017-03-02|    96|  1|John|     CRC|
# |          1|2017-03-03|   128|  1|John|     CRC|
# |          2|2020-01-13| 96516|  2|Jane|     EUR|
# |          1|2020-01-13| 86628|  1|John|     CRC|
# |          1|2017-03-01|   180|  1|John|     CRC|
# |          2|2017-03-03|    55|  2|Jane|     EUR|
# +-----------+----------+------+---+----+--------+

# %% [markdown]
# # Ejercicio
# - Cree un pequeño generador de transacciones. Para ello, puede utilizar funciones de numpy o pandas, para crear las transacciones nuevas en memoria y, posteriormente, puede cargarlas a un *Spark Dataframe* que después debe insertar en la base de datos.
# - Con los datos nuevos, ejecute el código de éste notebook.

# %% [markdown]
# # Configuración
# Para ejecutar el código de ejemplo en este notebook es necesario instalar Jupyter localmente. con soporte de Python. También es necesario instalar una serie de módulos utilizando el comando `pip`:
#
# ```bash
# pip3 install pyspark
# pip3 install findspark
# ```
#
# Referencias adicionales: [Spark](https://spark.apache.org/) y [PostgreSQL](https://www.postgresql.org/).
#
# # Referencias
# - Schutt, R; O'Neill C. Doing Data Science - Straight Talk from the Frontline. O'Reilly Media. 2013 (Capítulo 14)
# - Dean, J; Ghemawat, S. MapReduce: Simplified Data Processing on Large Clusters. https://static.googleusercontent.com/media/research.google.com/en//archive/mapreduce-osdi04.pdf
